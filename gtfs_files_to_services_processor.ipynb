# %%
import pandas as pd
from datetime import datetime, timedelta
import os
import re

# %%
# Configuration
SEARCH_FROM_YEAR  = 2019
SEARCH_FROM_MONTH = 1
SEARCH_FROM_DAY   = 1

SEARCH_TO_YEAR  = 2019
SEARCH_TO_MONTH = 12
SEARCH_TO_DAY   = 31

SEARCH_FROM_DATE = SEARCH_FROM_YEAR*10000 + SEARCH_FROM_MONTH*100 + SEARCH_FROM_DAY
SEARCH_TO_DATE = SEARCH_TO_YEAR*10000 + SEARCH_TO_MONTH*100 + SEARCH_TO_DAY

# Override to retrieve all dates' services
SEARCH_FROM_DATE = 10010101
SEARCH_TO_DATE = 99991231

# %%
extract_path = "./files/extracted/"
calendar_path = "/calendar.txt"
calendar_dates_path = "/calendar_dates.txt"

# calendar_pattern = r"calendar_\d+.*\.txt"
# calendar_dates_pattern = r"calendar_dates_\d+.*\.txt"

# calendar_files = [f for f in os.listdir(folder_path) if re.match(calendar_pattern, f)]
# calendar_dates_files = [f for f in os.listdir(folder_path) if re.match(calendar_dates_pattern, f)]

gtfs_generation_dates = [item for item in os.listdir(extract_path) if os.path.isdir(os.path.join(extract_path, item))]

# %%
def process_calendar_file(gtfs_generation_date):
    # Read the calendar.txt file into a DataFrame
    calendar = pd.read_csv(extract_path + gtfs_generation_date + calendar_path)

    # Convert the start_date and end_date columns to datetime objects
    calendar['start_date'] = pd.to_datetime(calendar['start_date'], format='%Y%m%d')
    calendar['end_date'] = pd.to_datetime(calendar['end_date'], format='%Y%m%d')

    # Generate a DataFrame with the service ID for each date
    dates = pd.DataFrame(columns=['date', 'service_id', 'gtfs_generation_date'])
    for _, row in calendar.iterrows():
        start_date = row['start_date']
        end_date = row['end_date']
        service_days = [int(x) for x in row[1:8]]
        service_id = row['service_id']
        for i in range((end_date - start_date).days + 1):
            date = start_date + timedelta(days=i)
            if service_days[date.weekday()] == 1:
                new_row = {'date': int(date.strftime('%Y%m%d')), 'service_id': service_id, 'gtfs_generation_date': gtfs_generation_date}
                # date will be retrieved as a int64
                # new_row = {'date': date, 'service_id': service_id, 'gtfs_generation_date': calendar_file[17:25]}
                dates = pd.concat([dates, pd.DataFrame(new_row, index=[0])])

    return(dates)

# %%
def process_calendar_dates_file(gtfs_generation_date):
    # Read the calendar_dates.txt file into a DataFrame
    calendar_dates = pd.read_csv(extract_path + gtfs_generation_date + calendar_dates_path)

    return(calendar_dates)

# %%
df_calendar = pd.DataFrame()
df_calendar_dates = pd.DataFrame()
# Set the path to the GTFS files
for gtfs_date in gtfs_generation_dates:
    # calendar_file = folder_path + filename # example: calendar_20181221.txt'
    df_calendar = pd.concat([df_calendar, process_calendar_file(gtfs_date)])
    df_calendar_dates = pd.concat([df_calendar_dates, process_calendar_dates_file(gtfs_date)])

# %%
# Group the DataFrame by date, service_id
calendar_grouped = df_calendar.groupby(['date', 'service_id'])

# Use the apply method to filter the DataFrame and select the rows with the maximum gtfs_generation_date for each group
calendar_result = calendar_grouped.apply(lambda x: x[x['gtfs_generation_date'] == x['gtfs_generation_date'].max()])

# Reset the index of the result DataFrame
calendar_result = calendar_result.reset_index(drop=True)

# Select the columns of interest
calendar_result = calendar_result[['date', 'service_id', 'gtfs_generation_date']]

# Retrieve unique calendar dates from aggregation of calendar_dates.txt
calendar_dates_unique_rows = df_calendar_dates.drop_duplicates(subset=['date', 'service_id', 'exception_type'])

# %%
# Calendar dates exception types decodes
# 1 - Service has been added for the specified date.
# 2 - Service has been removed for the specified date.

# Iterate through calendar_dates dataframe and make appropriate chnge to calendar_result
for index, row in calendar_dates_unique_rows.iterrows():
    service_id = row['service_id']
    exception_type = row['exception_type']
    
    
    # If exception type is 1, add service for specified date
    if exception_type == 1:
        date = row['date']
        new_row = {'service_id': service_id, 'date': date, 'exception_type': exception_type}
        print(new_row)
        # calendar_result = calendar_result.append(new_row, ignore_index=True)
        calendar_result = pd.concat([calendar_result, pd.DataFrame(new_row, index=[0])])

    # If exception type is 2, remove service for specified date
    elif exception_type == 2:
        date = row['date']
        calendar_result = calendar_result[~((calendar_result['service_id'] == service_id) & (calendar_result['date'] == date))]

# Clean calendar_result
calendar_result.reset_index(drop=True)
calendar_result = calendar_result[['date','service_id']]

# sort the DataFrame by the date column in ascending order
calendar_result = calendar_result.sort_values(by=['date','service_id'])
# Out:
# {'service_id': 'A20131215SUN', 'date': 20131225, 'exception_type': 1}
# {'service_id': 'A20131215SUN', 'date': 20140101, 'exception_type': 1}
# {'service_id': 'A20131215SAT', 'date': 20140217, 'exception_type': 1}
# {'service_id': 'A20131215SUN', 'date': 20140526, 'exception_type': 1}
# {'service_id': 'B20131215SUN', 'date': 20131225, 'exception_type': 1}
# {'service_id': 'B20131215SUN', 'date': 20140101, 'exception_type': 1}
# {'service_id': 'B20131215SAT', 'date': 20140217, 'exception_type': 1}
# {'service_id': 'B20131215SUN', 'date': 20140526, 'exception_type': 1}
# {'service_id': 'A20140608SAT', 'date': 20140704, 'exception_type': 1}
# {'service_id': 'A20140608SUN', 'date': 20140901, 'exception_type': 1}
# {'service_id': 'A20140608SUN', 'date': 20141127, 'exception_type': 1}
# {'service_id': 'B20140608SAT', 'date': 20140704, 'exception_type': 1}
# {'service_id': 'B20140608SUN', 'date': 20140901, 'exception_type': 1}
# {'service_id': 'B20140608SUN', 'date': 20141127, 'exception_type': 1}
# {'service_id': 'B20140608SUN_G', 'date': 20140901, 'exception_type': 1}
# {'service_id': 'B20140608SUN_G', 'date': 20141127, 'exception_type': 1}
# {'service_id': 'R20140615SAT', 'date': 20140704, 'exception_type': 1}
# {'service_id': 'R20140615SUN', 'date': 20140901, 'exception_type': 1}
# {'service_id': 'R20140615SUN', 'date': 20141127, 'exception_type': 1}
# {'service_id': 'greenpoint_fri_nightly', 'date': 20140613, 'exception_type': 1}
# {'service_id': 'greenpoint_fri_nightly', 'date': 20140704, 'exception_type': 1}
# {'service_id': 'greenpoint_fri_nightly', 'date': 20140711, 'exception_type': 1}
# {'service_id': 'greenpoint_mon_nightly', 'date': 20140616, 'exception_type': 1}
# {'service_id': 'greenpoint_mon_nightly', 'date': 20140707, 'exception_type': 1}
# {'service_id': 'greenpoint_mon_nightly', 'date': 20140714, 'exception_type': 1}
# {'service_id': 'greenpoint_nightly', 'date': 20140610, 'exception_type': 1}
# {'service_id': 'greenpoint_nightly', 'date': 20140611, 'exception_type': 1}
# {'service_id': 'greenpoint_nightly', 'date': 20140612, 'exception_type': 1}
# {'service_id': 'greenpoint_nightly', 'date': 20140617, 'exception_type': 1}
# {'service_id': 'greenpoint_nightly', 'date': 20140618, 'exception_type': 1}
# {'service_id': 'greenpoint_nightly', 'date': 20140619, 'exception_type': 1}
# {'service_id': 'greenpoint_nightly', 'date': 20140624, 'exception_type': 1}
# {'service_id': 'greenpoint_nightly', 'date': 20140625, 'exception_type': 1}
# {'service_id': 'greenpoint_nightly', 'date': 20140626, 'exception_type': 1}
# {'service_id': 'greenpoint_nightly', 'date': 20140701, 'exception_type': 1}
# {'service_id': 'greenpoint_nightly', 'date': 20140702, 'exception_type': 1}
# {'service_id': 'greenpoint_nightly', 'date': 20140703, 'exception_type': 1}
# {'service_id': 'greenpoint_nightly', 'date': 20140708, 'exception_type': 1}
# {'service_id': 'greenpoint_nightly', 'date': 20140709, 'exception_type': 1}
# {'service_id': 'greenpoint_nightly', 'date': 20140710, 'exception_type': 1}
# {'service_id': 'greenpoint_nightly', 'date': 20140715, 'exception_type': 1}
# {'service_id': 'greenpoint_nightly', 'date': 20140716, 'exception_type': 1}
# {'service_id': 'greenpoint_nightly', 'date': 20140717, 'exception_type': 1}
# {'service_id': 'greenpoint_nightly', 'date': 20140722, 'exception_type': 1}
# {'service_id': 'greenpoint_nightly', 'date': 20140723, 'exception_type': 1}
# {'service_id': 'greenpoint_nightly', 'date': 20140724, 'exception_type': 1}
# {'service_id': 'greenpoint_nightly_eve', 'date': 20140609, 'exception_type': 1}
# {'service_id': 'greenpoint_nightly_eve', 'date': 20140623, 'exception_type': 1}
# {'service_id': 'greenpoint_nightly_eve', 'date': 20140630, 'exception_type': 1}
# {'service_id': 'greenpoint_nightly_eve', 'date': 20140721, 'exception_type': 1}
# {'service_id': 'greenpoint_nightly_morn', 'date': 20140620, 'exception_type': 1}
# {'service_id': 'greenpoint_nightly_morn', 'date': 20140627, 'exception_type': 1}
# {'service_id': 'greenpoint_nightly_morn', 'date': 20140718, 'exception_type': 1}
# {'service_id': 'greenpoint_nightly_morn', 'date': 20140725, 'exception_type': 1}
# {'service_id': 'greenpoint_sat', 'date': 20140614, 'exception_type': 1}
# {'service_id': 'greenpoint_sat', 'date': 20140705, 'exception_type': 1}
# {'service_id': 'greenpoint_sat', 'date': 20140712, 'exception_type': 1}
# {'service_id': 'greenpoint_sun', 'date': 20140615, 'exception_type': 1}
# {'service_id': 'greenpoint_sun', 'date': 20140706, 'exception_type': 1}
# {'service_id': 'greenpoint_sun', 'date': 20140713, 'exception_type': 1}
# {'service_id': 'B20140608SAT_G', 'date': 20140704, 'exception_type': 1}
# {'service_id': 'greenpoint_24-7_reopen', 'date': 20140902, 'exception_type': 1}
# {'service_id': 'greenpoint_24-7_sat', 'date': 20140726, 'exception_type': 1}
# {'service_id': 'greenpoint_24-7_sat', 'date': 20140802, 'exception_type': 1}
# {'service_id': 'greenpoint_24-7_sat', 'date': 20140809, 'exception_type': 1}
# {'service_id': 'greenpoint_24-7_sat', 'date': 20140816, 'exception_type': 1}
# {'service_id': 'greenpoint_24-7_sat', 'date': 20140823, 'exception_type': 1}
# {'service_id': 'greenpoint_24-7_sat_8-30', 'date': 20140730, 'exception_type': 1}
# {'service_id': 'greenpoint_24-7_sun', 'date': 20140727, 'exception_type': 1}
# {'service_id': 'greenpoint_24-7_sun', 'date': 20140803, 'exception_type': 1}
# {'service_id': 'greenpoint_24-7_sun', 'date': 20140810, 'exception_type': 1}
# {'service_id': 'greenpoint_24-7_sun', 'date': 20140817, 'exception_type': 1}
# {'service_id': 'greenpoint_24-7_sun', 'date': 20140824, 'exception_type': 1}
# {'service_id': 'greenpoint_24-7_sun_8-31', 'date': 20140831, 'exception_type': 1}
# {'service_id': 'greenpoint_24-7_sun_9-1', 'date': 20140901, 'exception_type': 1}
# {'service_id': 'greenpoint_24-7_wkd', 'date': 20140728, 'exception_type': 1}
# {'service_id': 'greenpoint_24-7_wkd', 'date': 20140729, 'exception_type': 1}
# {'service_id': 'greenpoint_24-7_wkd', 'date': 20140730, 'exception_type': 1}
# {'service_id': 'greenpoint_24-7_wkd', 'date': 20140731, 'exception_type': 1}
# {'service_id': 'greenpoint_24-7_wkd', 'date': 20140801, 'exception_type': 1}
# {'service_id': 'greenpoint_24-7_wkd', 'date': 20140804, 'exception_type': 1}
# {'service_id': 'greenpoint_24-7_wkd', 'date': 20140805, 'exception_type': 1}
# {'service_id': 'greenpoint_24-7_wkd', 'date': 20140806, 'exception_type': 1}
# {'service_id': 'greenpoint_24-7_wkd', 'date': 20140807, 'exception_type': 1}
# {'service_id': 'greenpoint_24-7_wkd', 'date': 20140808, 'exception_type': 1}
# {'service_id': 'greenpoint_24-7_wkd', 'date': 20140811, 'exception_type': 1}
# {'service_id': 'greenpoint_24-7_wkd', 'date': 20140812, 'exception_type': 1}
# {'service_id': 'greenpoint_24-7_wkd', 'date': 20140813, 'exception_type': 1}
# {'service_id': 'greenpoint_24-7_wkd', 'date': 20140814, 'exception_type': 1}
# {'service_id': 'greenpoint_24-7_wkd', 'date': 20140815, 'exception_type': 1}
# {'service_id': 'greenpoint_24-7_wkd', 'date': 20140818, 'exception_type': 1}
# {'service_id': 'greenpoint_24-7_wkd', 'date': 20140819, 'exception_type': 1}
# {'service_id': 'greenpoint_24-7_wkd', 'date': 20140820, 'exception_type': 1}
# {'service_id': 'greenpoint_24-7_wkd', 'date': 20140821, 'exception_type': 1}
# {'service_id': 'greenpoint_24-7_wkd', 'date': 20140822, 'exception_type': 1}
# {'service_id': 'greenpoint_24-7_wkd', 'date': 20140825, 'exception_type': 1}
# {'service_id': 'greenpoint_24-7_wkd', 'date': 20140826, 'exception_type': 1}
# {'service_id': 'greenpoint_24-7_wkd', 'date': 20140827, 'exception_type': 1}
# {'service_id': 'greenpoint_24-7_wkd', 'date': 20140828, 'exception_type': 1}
# {'service_id': 'greenpoint_24-7_wkd', 'date': 20140829, 'exception_type': 1}
# {'service_id': 'greenpoint_fri_24-7', 'date': 20140725, 'exception_type': 1}
# {'service_id': 'greenpoint_24-7_sat_8-30', 'date': 20140830, 'exception_type': 1}
# {'service_id': 'B20140608SAT_N', 'date': 20140704, 'exception_type': 1}
# {'service_id': 'B20140608SUN_N', 'date': 20140901, 'exception_type': 1}
# {'service_id': 'montague_sat', 'date': 20140920, 'exception_type': 1}
# {'service_id': 'montague_sat', 'date': 20140927, 'exception_type': 1}
# {'service_id': 'montague_sat', 'date': 20141004, 'exception_type': 1}
# {'service_id': 'montague_sat', 'date': 20141011, 'exception_type': 1}
# {'service_id': 'montague_sat', 'date': 20141018, 'exception_type': 1}
# {'service_id': 'montague_sat', 'date': 20141025, 'exception_type': 1}
# {'service_id': 'montague_sat', 'date': 20141101, 'exception_type': 1}
# {'service_id': 'montague_sat', 'date': 20141108, 'exception_type': 1}
# {'service_id': 'montague_sat', 'date': 20141115, 'exception_type': 1}
# {'service_id': 'montague_sat', 'date': 20141122, 'exception_type': 1}
# {'service_id': 'montague_sat', 'date': 20141129, 'exception_type': 1}
# {'service_id': 'montague_sat', 'date': 20141206, 'exception_type': 1}
# {'service_id': 'montague_sat', 'date': 20141213, 'exception_type': 1}
# {'service_id': 'montague_sat', 'date': 20141220, 'exception_type': 1}
# {'service_id': 'montague_sat', 'date': 20141227, 'exception_type': 1}
# {'service_id': 'montague_sat', 'date': 20150103, 'exception_type': 1}
# {'service_id': 'montague_sat', 'date': 20150110, 'exception_type': 1}
# {'service_id': 'montague_sat', 'date': 20150117, 'exception_type': 1}
# {'service_id': 'montague_sat', 'date': 20150124, 'exception_type': 1}
# {'service_id': 'montague_sat', 'date': 20150131, 'exception_type': 1}
# {'service_id': 'montague_sat', 'date': 20150207, 'exception_type': 1}
# {'service_id': 'montague_sat', 'date': 20150214, 'exception_type': 1}
# {'service_id': 'montague_sat', 'date': 20150221, 'exception_type': 1}
# {'service_id': 'montague_sat', 'date': 20150228, 'exception_type': 1}
# {'service_id': 'montague_sat', 'date': 20150307, 'exception_type': 1}
# {'service_id': 'montague_sat', 'date': 20150314, 'exception_type': 1}
# {'service_id': 'montague_sat', 'date': 20150321, 'exception_type': 1}
# {'service_id': 'montague_sat', 'date': 20150328, 'exception_type': 1}
# {'service_id': 'montague_sat', 'date': 20150404, 'exception_type': 1}
# {'service_id': 'montague_sat', 'date': 20150411, 'exception_type': 1}
# {'service_id': 'montague_sat', 'date': 20150418, 'exception_type': 1}
# {'service_id': 'montague_sat', 'date': 20150425, 'exception_type': 1}
# {'service_id': 'montague_sat', 'date': 20150502, 'exception_type': 1}
# {'service_id': 'montague_sat', 'date': 20150509, 'exception_type': 1}
# {'service_id': 'montague_sat', 'date': 20150516, 'exception_type': 1}
# {'service_id': 'montague_sat', 'date': 20150523, 'exception_type': 1}
# {'service_id': 'montague_sat', 'date': 20150530, 'exception_type': 1}
# {'service_id': 'montague_sat', 'date': 20150606, 'exception_type': 1}
# {'service_id': 'montague_sat', 'date': 20150613, 'exception_type': 1}
# {'service_id': 'montague_sat', 'date': 20150620, 'exception_type': 1}
# {'service_id': 'montague_sat', 'date': 20150627, 'exception_type': 1}
# {'service_id': 'montague_sat', 'date': 20150704, 'exception_type': 1}
# {'service_id': 'montague_sat', 'date': 20150711, 'exception_type': 1}
# {'service_id': 'montague_sat', 'date': 20150718, 'exception_type': 1}
# {'service_id': 'montague_sat', 'date': 20150725, 'exception_type': 1}
# {'service_id': 'montague_sat', 'date': 20150801, 'exception_type': 1}
# {'service_id': 'montague_sat', 'date': 20150808, 'exception_type': 1}
# {'service_id': 'montague_sat', 'date': 20150815, 'exception_type': 1}
# {'service_id': 'montague_sat', 'date': 20150822, 'exception_type': 1}
# {'service_id': 'montague_sat', 'date': 20150829, 'exception_type': 1}
# {'service_id': 'montague_sat', 'date': 20150905, 'exception_type': 1}
# {'service_id': 'montague_sat', 'date': 20150912, 'exception_type': 1}
# {'service_id': 'montague_sat', 'date': 20150919, 'exception_type': 1}
# {'service_id': 'montague_sat', 'date': 20150926, 'exception_type': 1}
# {'service_id': 'montague_sat', 'date': 20151003, 'exception_type': 1}
# {'service_id': 'montague_sat', 'date': 20151010, 'exception_type': 1}
# {'service_id': 'montague_sat', 'date': 20151017, 'exception_type': 1}
# {'service_id': 'montague_sat', 'date': 20151024, 'exception_type': 1}
# {'service_id': 'montague_sat', 'date': 20151031, 'exception_type': 1}
# {'service_id': 'montague_sat', 'date': 20151107, 'exception_type': 1}
# {'service_id': 'montague_sat', 'date': 20151114, 'exception_type': 1}
# {'service_id': 'montague_sat', 'date': 20151121, 'exception_type': 1}
# {'service_id': 'montague_sat', 'date': 20151128, 'exception_type': 1}
# {'service_id': 'montague_sat', 'date': 20151205, 'exception_type': 1}
# {'service_id': 'montague_sat', 'date': 20151212, 'exception_type': 1}
# {'service_id': 'montague_sat', 'date': 20151219, 'exception_type': 1}
# {'service_id': 'montague_sat', 'date': 20151226, 'exception_type': 1}
# {'service_id': 'montague_sun', 'date': 20140914, 'exception_type': 1}
# {'service_id': 'montague_sun', 'date': 20140921, 'exception_type': 1}
# {'service_id': 'montague_sun', 'date': 20140928, 'exception_type': 1}
# {'service_id': 'montague_sun', 'date': 20141005, 'exception_type': 1}
# {'service_id': 'montague_sun', 'date': 20141012, 'exception_type': 1}
# {'service_id': 'montague_sun', 'date': 20141019, 'exception_type': 1}
# {'service_id': 'montague_sun', 'date': 20141026, 'exception_type': 1}
# {'service_id': 'montague_sun', 'date': 20141102, 'exception_type': 1}
# {'service_id': 'montague_sun', 'date': 20141109, 'exception_type': 1}
# {'service_id': 'montague_sun', 'date': 20141116, 'exception_type': 1}
# {'service_id': 'montague_sun', 'date': 20141123, 'exception_type': 1}
# {'service_id': 'montague_sun', 'date': 20141130, 'exception_type': 1}
# {'service_id': 'montague_sun', 'date': 20141207, 'exception_type': 1}
# {'service_id': 'montague_sun', 'date': 20141214, 'exception_type': 1}
# {'service_id': 'montague_sun', 'date': 20141221, 'exception_type': 1}
# {'service_id': 'montague_sun', 'date': 20141228, 'exception_type': 1}
# {'service_id': 'montague_sun', 'date': 20150104, 'exception_type': 1}
# {'service_id': 'montague_sun', 'date': 20150111, 'exception_type': 1}
# {'service_id': 'montague_sun', 'date': 20150118, 'exception_type': 1}
# {'service_id': 'montague_sun', 'date': 20150125, 'exception_type': 1}
# {'service_id': 'montague_sun', 'date': 20150201, 'exception_type': 1}
# {'service_id': 'montague_sun', 'date': 20150208, 'exception_type': 1}
# {'service_id': 'montague_sun', 'date': 20150215, 'exception_type': 1}
# {'service_id': 'montague_sun', 'date': 20150222, 'exception_type': 1}
# {'service_id': 'montague_sun', 'date': 20150301, 'exception_type': 1}
# {'service_id': 'montague_sun', 'date': 20150308, 'exception_type': 1}
# {'service_id': 'montague_sun', 'date': 20150315, 'exception_type': 1}
# {'service_id': 'montague_sun', 'date': 20150322, 'exception_type': 1}
# {'service_id': 'montague_sun', 'date': 20150329, 'exception_type': 1}
# {'service_id': 'montague_sun', 'date': 20150405, 'exception_type': 1}
# {'service_id': 'montague_sun', 'date': 20150412, 'exception_type': 1}
# {'service_id': 'montague_sun', 'date': 20150419, 'exception_type': 1}
# {'service_id': 'montague_sun', 'date': 20150426, 'exception_type': 1}
# {'service_id': 'montague_sun', 'date': 20150503, 'exception_type': 1}
# {'service_id': 'montague_sun', 'date': 20150510, 'exception_type': 1}
# {'service_id': 'montague_sun', 'date': 20150517, 'exception_type': 1}
# {'service_id': 'montague_sun', 'date': 20150524, 'exception_type': 1}
# {'service_id': 'montague_sun', 'date': 20150531, 'exception_type': 1}
# {'service_id': 'montague_sun', 'date': 20150607, 'exception_type': 1}
# {'service_id': 'montague_sun', 'date': 20150614, 'exception_type': 1}
# {'service_id': 'montague_sun', 'date': 20150621, 'exception_type': 1}
# {'service_id': 'montague_sun', 'date': 20150628, 'exception_type': 1}
# {'service_id': 'montague_sun', 'date': 20150705, 'exception_type': 1}
# {'service_id': 'montague_sun', 'date': 20150712, 'exception_type': 1}
# {'service_id': 'montague_sun', 'date': 20150719, 'exception_type': 1}
# {'service_id': 'montague_sun', 'date': 20150726, 'exception_type': 1}
# {'service_id': 'montague_sun', 'date': 20150802, 'exception_type': 1}
# {'service_id': 'montague_sun', 'date': 20150809, 'exception_type': 1}
# {'service_id': 'montague_sun', 'date': 20150816, 'exception_type': 1}
# {'service_id': 'montague_sun', 'date': 20150823, 'exception_type': 1}
# {'service_id': 'montague_sun', 'date': 20150830, 'exception_type': 1}
# {'service_id': 'montague_sun', 'date': 20150906, 'exception_type': 1}
# {'service_id': 'montague_sun', 'date': 20150913, 'exception_type': 1}
# {'service_id': 'montague_sun', 'date': 20150920, 'exception_type': 1}
# {'service_id': 'montague_sun', 'date': 20150927, 'exception_type': 1}
# {'service_id': 'montague_sun', 'date': 20151004, 'exception_type': 1}
# {'service_id': 'montague_sun', 'date': 20151011, 'exception_type': 1}
# {'service_id': 'montague_sun', 'date': 20151018, 'exception_type': 1}
# {'service_id': 'montague_sun', 'date': 20151025, 'exception_type': 1}
# {'service_id': 'montague_sun', 'date': 20151101, 'exception_type': 1}
# {'service_id': 'montague_sun', 'date': 20151108, 'exception_type': 1}
# {'service_id': 'montague_sun', 'date': 20151115, 'exception_type': 1}
# {'service_id': 'montague_sun', 'date': 20151122, 'exception_type': 1}
# {'service_id': 'montague_sun', 'date': 20151129, 'exception_type': 1}
# {'service_id': 'montague_sun', 'date': 20151206, 'exception_type': 1}
# {'service_id': 'montague_sun', 'date': 20151213, 'exception_type': 1}
# {'service_id': 'montague_sun', 'date': 20151220, 'exception_type': 1}
# {'service_id': 'montague_sun', 'date': 20151227, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20140915, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20140916, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20140917, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20140918, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20140919, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20140922, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20140923, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20140924, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20140925, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20140926, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20140929, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20140930, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20141001, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20141002, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20141003, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20141006, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20141007, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20141008, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20141009, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20141010, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20141013, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20141014, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20141015, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20141016, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20141017, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20141020, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20141021, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20141022, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20141023, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20141024, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20141027, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20141028, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20141029, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20141030, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20141031, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20141103, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20141104, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20141105, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20141106, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20141107, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20141110, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20141111, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20141112, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20141113, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20141114, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20141117, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20141118, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20141119, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20141120, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20141121, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20141124, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20141125, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20141126, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20141127, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20141128, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20141201, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20141202, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20141203, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20141204, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20141205, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20141208, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20141209, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20141210, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20141211, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20141212, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20141215, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20141216, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20141217, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20141218, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20141219, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20141222, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20141223, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20141224, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20141225, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20141226, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20141229, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20141230, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20141231, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150101, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150102, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150105, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150106, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150107, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150108, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150109, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150112, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150113, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150114, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150115, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150116, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150119, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150120, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150121, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150122, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150123, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150126, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150127, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150128, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150129, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150130, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150202, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150203, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150204, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150205, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150206, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150209, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150210, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150211, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150212, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150213, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150216, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150217, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150218, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150219, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150220, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150223, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150224, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150225, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150226, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150227, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150302, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150303, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150304, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150305, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150306, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150309, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150310, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150311, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150312, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150313, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150316, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150317, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150318, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150319, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150320, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150323, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150324, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150325, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150326, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150327, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150330, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150331, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150401, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150402, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150403, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150406, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150407, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150408, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150409, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150410, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150413, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150414, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150415, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150416, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150417, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150420, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150421, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150422, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150423, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150424, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150427, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150428, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150429, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150430, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150501, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150504, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150505, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150506, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150507, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150508, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150511, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150512, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150513, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150514, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150515, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150518, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150519, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150520, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150521, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150522, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150525, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150526, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150527, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150528, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150529, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150601, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150602, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150603, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150604, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150605, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150608, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150609, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150610, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150611, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150612, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150615, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150616, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150617, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150618, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150619, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150622, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150623, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150624, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150625, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150626, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150629, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150630, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150701, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150702, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150703, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150706, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150707, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150708, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150709, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150710, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150713, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150714, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150715, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150716, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150717, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150720, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150721, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150722, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150723, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150724, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150727, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150728, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150729, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150730, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150731, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150803, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150804, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150805, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150806, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150807, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150810, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150811, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150812, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150813, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150814, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150817, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150818, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150819, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150820, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150821, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150824, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150825, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150826, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150827, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150828, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150831, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150901, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150902, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150903, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150904, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150907, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150908, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150909, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150910, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150911, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150914, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150915, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150916, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150917, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150918, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150921, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150922, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150923, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150924, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150925, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150928, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150929, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20150930, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20151001, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20151002, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20151005, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20151006, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20151007, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20151008, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20151009, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20151012, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20151013, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20151014, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20151015, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20151016, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20151019, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20151020, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20151021, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20151022, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20151023, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20151026, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20151027, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20151028, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20151029, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20151030, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20151102, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20151103, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20151104, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20151105, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20151106, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20151109, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20151110, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20151111, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20151112, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20151113, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20151116, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20151117, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20151118, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20151119, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20151120, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20151123, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20151124, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20151125, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20151126, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20151127, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20151130, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20151201, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20151202, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20151203, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20151204, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20151207, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20151208, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20151209, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20151210, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20151211, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20151214, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20151215, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20151216, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20151217, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20151218, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20151221, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20151222, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20151223, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20151224, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20151225, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20151228, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20151229, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20151230, 'exception_type': 1}
# {'service_id': 'montague_wkd', 'date': 20151231, 'exception_type': 1}
# {'service_id': 'A20141207SUN', 'date': 20150101, 'exception_type': 1}
# {'service_id': 'A20141207SAT', 'date': 20150216, 'exception_type': 1}
# {'service_id': 'A20141207SUN', 'date': 20150525, 'exception_type': 1}
# {'service_id': 'B20141207SUN', 'date': 20150101, 'exception_type': 1}
# {'service_id': 'B20141207SAT', 'date': 20150216, 'exception_type': 1}
# {'service_id': 'B20141207SUN', 'date': 20150525, 'exception_type': 1}
# {'service_id': 'A20150614SUN', 'date': 20150907, 'exception_type': 1}
# {'service_id': 'A20150614SUN', 'date': 20151126, 'exception_type': 1}
# {'service_id': 'B20150614SUN', 'date': 20150907, 'exception_type': 1}
# {'service_id': 'B20150614SUN', 'date': 20151126, 'exception_type': 1}
# {'service_id': 'A20150614SUN', 'date': 20151225, 'exception_type': 1}
# {'service_id': 'A20151206SUN', 'date': 20160101, 'exception_type': 1}
# {'service_id': 'A20151206SAT', 'date': 20160215, 'exception_type': 1}
# {'service_id': 'A20151206SUN', 'date': 20160530, 'exception_type': 1}
# {'service_id': 'B20151206SUN', 'date': 20151225, 'exception_type': 1}
# {'service_id': 'B20151206SUN', 'date': 20160101, 'exception_type': 1}
# {'service_id': 'B20151206SAT', 'date': 20160215, 'exception_type': 1}
# {'service_id': 'B20151206SUN', 'date': 20160530, 'exception_type': 1}
# {'service_id': 'A20160612SAT', 'date': 20160704, 'exception_type': 1}
# {'service_id': 'A20160612SUN', 'date': 20160905, 'exception_type': 1}
# {'service_id': 'A20160612SUN', 'date': 20161124, 'exception_type': 1}
# {'service_id': 'B20160612SAT', 'date': 20160704, 'exception_type': 1}
# {'service_id': 'B20160612SUN', 'date': 20160905, 'exception_type': 1}
# {'service_id': 'B20160612SUN', 'date': 20161124, 'exception_type': 1}
# {'service_id': 'A20161106SUN', 'date': 20161124, 'exception_type': 1}
# {'service_id': 'A20161106SUN', 'date': 20161226, 'exception_type': 1}
# {'service_id': 'A20161106SUN', 'date': 20170102, 'exception_type': 1}
# {'service_id': 'A20161106SAT', 'date': 20170220, 'exception_type': 1}
# {'service_id': 'B20161106SUN', 'date': 20161124, 'exception_type': 1}
# {'service_id': 'B20161106SUN', 'date': 20161226, 'exception_type': 1}
# {'service_id': 'B20161106SUN', 'date': 20170102, 'exception_type': 1}
# {'service_id': 'B20161106SAT', 'date': 20170220, 'exception_type': 1}
# {'service_id': 'R20161106SUN', 'date': 20161124, 'exception_type': 1}
# {'service_id': 'R20161106SUN', 'date': 20161226, 'exception_type': 1}
# {'service_id': 'R20161106SUN', 'date': 20170102, 'exception_type': 1}
# {'service_id': 'R20161106SAT', 'date': 20170220, 'exception_type': 1}
# {'service_id': 'A20170625SAT', 'date': 20170704, 'exception_type': 1}
# {'service_id': 'A20170625SUN', 'date': 20170904, 'exception_type': 1}
# {'service_id': 'B20170625SAT', 'date': 20170704, 'exception_type': 1}
# {'service_id': 'B20170625SUN', 'date': 20170904, 'exception_type': 1}
# {'service_id': 'A20171105SUN', 'date': 20171123, 'exception_type': 1}
# {'service_id': 'A20171105SUN', 'date': 20171225, 'exception_type': 1}
# {'service_id': 'A20171105SUN', 'date': 20180101, 'exception_type': 1}
# {'service_id': 'A20171105SAT', 'date': 20180219, 'exception_type': 1}
# {'service_id': 'A20171105SUN', 'date': 20180528, 'exception_type': 1}
# {'service_id': 'B20171105SUN', 'date': 20171123, 'exception_type': 1}
# {'service_id': 'B20171105SUN', 'date': 20171225, 'exception_type': 1}
# {'service_id': 'B20171105SUN', 'date': 20180101, 'exception_type': 1}
# {'service_id': 'B20171105SAT', 'date': 20180219, 'exception_type': 1}
# {'service_id': 'B20171105SUN', 'date': 20180528, 'exception_type': 1}
# {'service_id': 'R20171105SUN', 'date': 20171123, 'exception_type': 1}
# {'service_id': 'R20171105SUN', 'date': 20171225, 'exception_type': 1}
# {'service_id': 'R20171105SUN', 'date': 20180101, 'exception_type': 1}
# {'service_id': 'R20171105SAT', 'date': 20180219, 'exception_type': 1}
# {'service_id': 'R20171105SUN', 'date': 20180528, 'exception_type': 1}
# {'service_id': 'ASP18GEN-1037-Sunday-00', 'date': 20180903, 'exception_type': 1}
# {'service_id': 'ASP18GEN-2048-Sunday-00', 'date': 20180903, 'exception_type': 1}
# {'service_id': 'ASP18GEN-3041-Sunday-00', 'date': 20180903, 'exception_type': 1}
# {'service_id': 'ASP18GEN-4049-Sunday-00', 'date': 20180903, 'exception_type': 1}
# {'service_id': 'ASP18GEN-5048-Sunday-00', 'date': 20180903, 'exception_type': 1}
# {'service_id': 'ASP18GEN-6030-Sunday-00', 'date': 20180903, 'exception_type': 1}
# {'service_id': 'ASP18GEN-7025-Sunday-00', 'date': 20180903, 'exception_type': 1}
# {'service_id': 'BSP18GEN-A051-Sunday-00', 'date': 20180903, 'exception_type': 1}
# {'service_id': 'BSP18GEN-C026-Sunday-00', 'date': 20180903, 'exception_type': 1}
# {'service_id': 'BSP18GEN-D040-Sunday-00', 'date': 20180903, 'exception_type': 1}
# {'service_id': 'BSP18GEN-E044-Sunday-00', 'date': 20180903, 'exception_type': 1}
# {'service_id': 'BSP18GEN-F048-Sunday-00', 'date': 20180903, 'exception_type': 1}
# {'service_id': 'BSP18GEN-FS012-Sunday-00', 'date': 20180903, 'exception_type': 1}
# {'service_id': 'BSP18GEN-G034-Sunday-00', 'date': 20180903, 'exception_type': 1}
# {'service_id': 'ASP18GEN-GS010-Sunday-00', 'date': 20180903, 'exception_type': 1}
# {'service_id': 'BSP18GEN-H024-Sunday-00', 'date': 20180903, 'exception_type': 1}
# {'service_id': 'BSP18GEN-J032-Sunday-00', 'date': 20180903, 'exception_type': 1}
# {'service_id': 'BSP18GEN-L022-Sunday-00', 'date': 20180903, 'exception_type': 1}
# {'service_id': 'BSP18GEN-M023-Sunday-00', 'date': 20180903, 'exception_type': 1}
# {'service_id': 'BSP18GEN-N057-Sunday-00', 'date': 20180903, 'exception_type': 1}
# {'service_id': 'BSP18GEN-Q022-Sunday-00', 'date': 20180903, 'exception_type': 1}
# {'service_id': 'BSP18GEN-R049-Sunday-00', 'date': 20180903, 'exception_type': 1}
# {'service_id': 'ASP18GEN-1038-Saturday-00', 'date': 20180704, 'exception_type': 1}
# {'service_id': 'ASP18GEN-2042-Saturday-00', 'date': 20180704, 'exception_type': 1}
# {'service_id': 'ASP18GEN-3039-Saturday-00', 'date': 20180704, 'exception_type': 1}
# {'service_id': 'ASP18GEN-4043-Saturday-00', 'date': 20180704, 'exception_type': 1}
# {'service_id': 'ASP18GEN-5043-Saturday-00', 'date': 20180704, 'exception_type': 1}
# {'service_id': 'ASP18GEN-6033-Saturday-00', 'date': 20180704, 'exception_type': 1}
# {'service_id': 'ASP18GEN-7023-Saturday-00', 'date': 20180704, 'exception_type': 1}
# {'service_id': 'BSP18GEN-A044-Saturday-00', 'date': 20180704, 'exception_type': 1}
# {'service_id': 'BSP18GEN-C024-Saturday-00', 'date': 20180704, 'exception_type': 1}
# {'service_id': 'BSP18GEN-D037-Saturday-00', 'date': 20180704, 'exception_type': 1}
# {'service_id': 'BSP18GEN-E039-Saturday-00', 'date': 20180704, 'exception_type': 1}
# {'service_id': 'BSP18GEN-F044-Saturday-00', 'date': 20180704, 'exception_type': 1}
# {'service_id': 'BSP18GEN-FS011-Saturday-00', 'date': 20180704, 'exception_type': 1}
# {'service_id': 'BSP18GEN-G033-Saturday-00', 'date': 20180704, 'exception_type': 1}
# {'service_id': 'ASP18GEN-GS010-Saturday-00', 'date': 20180704, 'exception_type': 1}
# ...
# {'service_id': 'BFA21GEN-F044-Saturday-00', 'date': 20220221, 'exception_type': 1}
# {'service_id': 'BFA21GEN-FS011-Saturday-00', 'date': 20211224, 'exception_type': 1}
# {'service_id': 'BFA21GEN-FS011-Saturday-00', 'date': 20211231, 'exception_type': 1}
# {'service_id': 'BFA21GEN-FS011-Saturday-00', 'date': 20220221, 'exception_type': 1}
# {'service_id': 'BFA21GEN-G036-Saturday-00', 'date': 20211224, 'exception_type': 1}
# {'service_id': 'BFA21GEN-G036-Saturday-00', 'date': 20211231, 'exception_type': 1}
# {'service_id': 'BFA21GEN-G036-Saturday-00', 'date': 20220221, 'exception_type': 1}
# {'service_id': 'AFA21GEN-GS013-Saturday-00', 'date': 20211224, 'exception_type': 1}
# {'service_id': 'AFA21GEN-GS013-Saturday-00', 'date': 20211231, 'exception_type': 1}
# {'service_id': 'AFA21GEN-GS013-Saturday-00', 'date': 20220221, 'exception_type': 1}
# {'service_id': 'BFA21GEN-H026-Saturday-00', 'date': 20211224, 'exception_type': 1}
# {'service_id': 'BFA21GEN-H026-Saturday-00', 'date': 20211231, 'exception_type': 1}
# {'service_id': 'BFA21GEN-H026-Saturday-00', 'date': 20220221, 'exception_type': 1}
# {'service_id': 'BFA21GEN-J032-Saturday-00', 'date': 20211224, 'exception_type': 1}
# {'service_id': 'BFA21GEN-J032-Saturday-00', 'date': 20211231, 'exception_type': 1}
# {'service_id': 'BFA21GEN-J032-Saturday-00', 'date': 20220221, 'exception_type': 1}
# {'service_id': 'BFA21GEN-L022-Saturday-00', 'date': 20211224, 'exception_type': 1}
# {'service_id': 'BFA21GEN-L022-Saturday-00', 'date': 20211231, 'exception_type': 1}
# {'service_id': 'BFA21GEN-L022-Saturday-00', 'date': 20220221, 'exception_type': 1}
# {'service_id': 'BFA21GEN-M024-Saturday-00', 'date': 20211224, 'exception_type': 1}
# {'service_id': 'BFA21GEN-M024-Saturday-00', 'date': 20211231, 'exception_type': 1}
# {'service_id': 'BFA21GEN-M024-Saturday-00', 'date': 20220221, 'exception_type': 1}
# {'service_id': 'BFA21GEN-N056-Saturday-00', 'date': 20211224, 'exception_type': 1}
# {'service_id': 'BFA21GEN-N056-Saturday-00', 'date': 20211231, 'exception_type': 1}
# {'service_id': 'BFA21GEN-N056-Saturday-00', 'date': 20220221, 'exception_type': 1}
# {'service_id': 'BFA21GEN-Q021-Saturday-00', 'date': 20211224, 'exception_type': 1}
# {'service_id': 'BFA21GEN-Q021-Saturday-00', 'date': 20211231, 'exception_type': 1}
# {'service_id': 'BFA21GEN-Q021-Saturday-00', 'date': 20220221, 'exception_type': 1}
# {'service_id': 'BFA21GEN-R051-Saturday-00', 'date': 20211224, 'exception_type': 1}
# {'service_id': 'BFA21GEN-R051-Saturday-00', 'date': 20211231, 'exception_type': 1}
# {'service_id': 'BFA21GEN-R051-Saturday-00', 'date': 20220221, 'exception_type': 1}
# {'service_id': 'SIR-FA2017-SI017-Saturday-00', 'date': 20211224, 'exception_type': 1}
# {'service_id': 'SIR-FA2017-SI017-Saturday-00', 'date': 20211231, 'exception_type': 1}
# {'service_id': 'SIR-FA2017-SI017-Saturday-00', 'date': 20220221, 'exception_type': 1}
# {'service_id': 'ASP22GEN-1037-Sunday-00', 'date': 20220905, 'exception_type': 1}
# {'service_id': 'ASP22GEN-1037-Sunday-00', 'date': 20221124, 'exception_type': 1}
# {'service_id': 'ASP22GEN-2048-Sunday-00', 'date': 20220905, 'exception_type': 1}
# {'service_id': 'ASP22GEN-2048-Sunday-00', 'date': 20221124, 'exception_type': 1}
# {'service_id': 'ASP22GEN-3041-Sunday-00', 'date': 20220905, 'exception_type': 1}
# {'service_id': 'ASP22GEN-3041-Sunday-00', 'date': 20221124, 'exception_type': 1}
# {'service_id': 'ASP22GEN-4049-Sunday-00', 'date': 20220905, 'exception_type': 1}
# {'service_id': 'ASP22GEN-4049-Sunday-00', 'date': 20221124, 'exception_type': 1}
# {'service_id': 'ASP22GEN-5048-Sunday-00', 'date': 20220905, 'exception_type': 1}
# {'service_id': 'ASP22GEN-5048-Sunday-00', 'date': 20221124, 'exception_type': 1}
# {'service_id': 'ASP22GEN-6030-Sunday-00', 'date': 20220905, 'exception_type': 1}
# {'service_id': 'ASP22GEN-6030-Sunday-00', 'date': 20221124, 'exception_type': 1}
# {'service_id': 'ASP22GEN-7025-Sunday-00', 'date': 20220905, 'exception_type': 1}
# {'service_id': 'ASP22GEN-7025-Sunday-00', 'date': 20221124, 'exception_type': 1}
# {'service_id': 'BSP22GEN-A054-Sunday-00', 'date': 20220905, 'exception_type': 1}
# {'service_id': 'BSP22GEN-A054-Sunday-00', 'date': 20221124, 'exception_type': 1}
# {'service_id': 'BSP22GEN-C027-Sunday-00', 'date': 20220905, 'exception_type': 1}
# {'service_id': 'BSP22GEN-C027-Sunday-00', 'date': 20221124, 'exception_type': 1}
# {'service_id': 'BSP22GEN-D042-Sunday-00', 'date': 20220905, 'exception_type': 1}
# {'service_id': 'BSP22GEN-D042-Sunday-00', 'date': 20221124, 'exception_type': 1}
# {'service_id': 'BSP22GEN-E046-Sunday-00', 'date': 20220905, 'exception_type': 1}
# {'service_id': 'BSP22GEN-E046-Sunday-00', 'date': 20221124, 'exception_type': 1}
# {'service_id': 'BSP22GEN-F048-Sunday-00', 'date': 20220905, 'exception_type': 1}
# {'service_id': 'BSP22GEN-F048-Sunday-00', 'date': 20221124, 'exception_type': 1}
# {'service_id': 'BSP22GEN-FS012-Sunday-00', 'date': 20220905, 'exception_type': 1}
# {'service_id': 'BSP22GEN-FS012-Sunday-00', 'date': 20221124, 'exception_type': 1}
# {'service_id': 'BSP22GEN-G037-Sunday-00', 'date': 20220905, 'exception_type': 1}
# {'service_id': 'BSP22GEN-G037-Sunday-00', 'date': 20221124, 'exception_type': 1}
# {'service_id': 'ASP22GEN-GS013-Sunday-00', 'date': 20220905, 'exception_type': 1}
# {'service_id': 'ASP22GEN-GS013-Sunday-00', 'date': 20221124, 'exception_type': 1}
# {'service_id': 'BSP22GEN-H025-Sunday-00', 'date': 20220905, 'exception_type': 1}
# {'service_id': 'BSP22GEN-H025-Sunday-00', 'date': 20221124, 'exception_type': 1}
# {'service_id': 'BSP22GEN-J032-Sunday-00', 'date': 20220905, 'exception_type': 1}
# {'service_id': 'BSP22GEN-J032-Sunday-00', 'date': 20221124, 'exception_type': 1}
# {'service_id': 'BSP22GEN-L022-Sunday-00', 'date': 20220905, 'exception_type': 1}
# {'service_id': 'BSP22GEN-L022-Sunday-00', 'date': 20221124, 'exception_type': 1}
# {'service_id': 'BSP22GEN-M023-Sunday-00', 'date': 20220905, 'exception_type': 1}
# {'service_id': 'BSP22GEN-M023-Sunday-00', 'date': 20221124, 'exception_type': 1}
# {'service_id': 'BSP22GEN-N059-Sunday-00', 'date': 20220905, 'exception_type': 1}
# {'service_id': 'BSP22GEN-N059-Sunday-00', 'date': 20221124, 'exception_type': 1}
# {'service_id': 'BSP22GEN-Q023-Sunday-00', 'date': 20220905, 'exception_type': 1}
# {'service_id': 'BSP22GEN-Q023-Sunday-00', 'date': 20221124, 'exception_type': 1}
# {'service_id': 'BSP22GEN-R050-Sunday-00', 'date': 20220905, 'exception_type': 1}
# {'service_id': 'BSP22GEN-R050-Sunday-00', 'date': 20221124, 'exception_type': 1}
# {'service_id': 'ASP22GEN-1038-Saturday-00', 'date': 20220704, 'exception_type': 1}
# {'service_id': 'ASP22GEN-2042-Saturday-00', 'date': 20220704, 'exception_type': 1}
# {'service_id': 'ASP22GEN-3039-Saturday-00', 'date': 20220704, 'exception_type': 1}
# {'service_id': 'ASP22GEN-4043-Saturday-00', 'date': 20220704, 'exception_type': 1}
# {'service_id': 'ASP22GEN-5043-Saturday-00', 'date': 20220704, 'exception_type': 1}
# {'service_id': 'ASP22GEN-6033-Saturday-00', 'date': 20220704, 'exception_type': 1}
# {'service_id': 'ASP22GEN-7023-Saturday-00', 'date': 20220704, 'exception_type': 1}
# {'service_id': 'BSP22GEN-A046-Saturday-00', 'date': 20220704, 'exception_type': 1}
# {'service_id': 'BSP22GEN-C025-Saturday-00', 'date': 20220704, 'exception_type': 1}
# {'service_id': 'BSP22GEN-D039-Saturday-00', 'date': 20220704, 'exception_type': 1}
# {'service_id': 'BSP22GEN-E041-Saturday-00', 'date': 20220704, 'exception_type': 1}
# {'service_id': 'BSP22GEN-F044-Saturday-00', 'date': 20220704, 'exception_type': 1}
# {'service_id': 'BSP22GEN-FS011-Saturday-00', 'date': 20220704, 'exception_type': 1}
# {'service_id': 'BSP22GEN-G036-Saturday-00', 'date': 20220704, 'exception_type': 1}
# {'service_id': 'ASP22GEN-GS013-Saturday-00', 'date': 20220704, 'exception_type': 1}
# {'service_id': 'BSP22GEN-H026-Saturday-00', 'date': 20220704, 'exception_type': 1}
# {'service_id': 'BSP22GEN-J032-Saturday-00', 'date': 20220704, 'exception_type': 1}
# {'service_id': 'BSP22GEN-L022-Saturday-00', 'date': 20220704, 'exception_type': 1}
# {'service_id': 'BSP22GEN-M024-Saturday-00', 'date': 20220704, 'exception_type': 1}
# {'service_id': 'BSP22GEN-N056-Saturday-00', 'date': 20220704, 'exception_type': 1}
# {'service_id': 'BSP22GEN-Q021-Saturday-00', 'date': 20220704, 'exception_type': 1}
# {'service_id': 'BSP22GEN-R051-Saturday-00', 'date': 20220704, 'exception_type': 1}
# {'service_id': 'SIR-FA2018-SI017-Saturday-00', 'date': 20220704, 'exception_type': 1}
# {'service_id': 'SIR-FA2018-SI017-Sunday-00', 'date': 20220905, 'exception_type': 1}
# {'service_id': 'SIR-SP2018-SI017-Sunday-00', 'date': 20221124, 'exception_type': 1}
# {'service_id': 'AFA22GEN-1037-Sunday-00', 'date': 20221226, 'exception_type': 1}
# {'service_id': 'AFA22GEN-1037-Sunday-00', 'date': 20230102, 'exception_type': 1}
# {'service_id': 'AFA22GEN-1037-Sunday-00', 'date': 20230529, 'exception_type': 1}
# {'service_id': 'AFA22GEN-2048-Sunday-00', 'date': 20221226, 'exception_type': 1}
# {'service_id': 'AFA22GEN-2048-Sunday-00', 'date': 20230102, 'exception_type': 1}
# {'service_id': 'AFA22GEN-2048-Sunday-00', 'date': 20230529, 'exception_type': 1}
# {'service_id': 'AFA22GEN-3041-Sunday-00', 'date': 20221226, 'exception_type': 1}
# {'service_id': 'AFA22GEN-3041-Sunday-00', 'date': 20230102, 'exception_type': 1}
# {'service_id': 'AFA22GEN-3041-Sunday-00', 'date': 20230529, 'exception_type': 1}
# {'service_id': 'AFA22GEN-4049-Sunday-00', 'date': 20221226, 'exception_type': 1}
# {'service_id': 'AFA22GEN-4049-Sunday-00', 'date': 20230102, 'exception_type': 1}
# {'service_id': 'AFA22GEN-4049-Sunday-00', 'date': 20230529, 'exception_type': 1}
# {'service_id': 'AFA22GEN-5048-Sunday-00', 'date': 20221226, 'exception_type': 1}
# {'service_id': 'AFA22GEN-5048-Sunday-00', 'date': 20230102, 'exception_type': 1}
# {'service_id': 'AFA22GEN-5048-Sunday-00', 'date': 20230529, 'exception_type': 1}
# {'service_id': 'AFA22GEN-6030-Sunday-00', 'date': 20221226, 'exception_type': 1}
# {'service_id': 'AFA22GEN-6030-Sunday-00', 'date': 20230102, 'exception_type': 1}
# {'service_id': 'AFA22GEN-6030-Sunday-00', 'date': 20230529, 'exception_type': 1}
# {'service_id': 'AFA22GEN-7025-Sunday-00', 'date': 20221226, 'exception_type': 1}
# {'service_id': 'AFA22GEN-7025-Sunday-00', 'date': 20230102, 'exception_type': 1}
# {'service_id': 'AFA22GEN-7025-Sunday-00', 'date': 20230529, 'exception_type': 1}
# {'service_id': 'BFA22GEN-A054-Sunday-00', 'date': 20221226, 'exception_type': 1}
# {'service_id': 'BFA22GEN-A054-Sunday-00', 'date': 20230102, 'exception_type': 1}
# {'service_id': 'BFA22GEN-A054-Sunday-00', 'date': 20230529, 'exception_type': 1}
# {'service_id': 'BFA22GEN-C027-Sunday-00', 'date': 20221226, 'exception_type': 1}
# {'service_id': 'BFA22GEN-C027-Sunday-00', 'date': 20230102, 'exception_type': 1}
# {'service_id': 'BFA22GEN-C027-Sunday-00', 'date': 20230529, 'exception_type': 1}
# {'service_id': 'BFA22GEN-D042-Sunday-00', 'date': 20221226, 'exception_type': 1}
# {'service_id': 'BFA22GEN-D042-Sunday-00', 'date': 20230102, 'exception_type': 1}
# {'service_id': 'BFA22GEN-D042-Sunday-00', 'date': 20230529, 'exception_type': 1}
# {'service_id': 'BFA22GEN-E047-Sunday-00', 'date': 20221226, 'exception_type': 1}
# {'service_id': 'BFA22GEN-E047-Sunday-00', 'date': 20230102, 'exception_type': 1}
# {'service_id': 'BFA22GEN-E047-Sunday-00', 'date': 20230529, 'exception_type': 1}
# {'service_id': 'BFA22GEN-F048-Sunday-00', 'date': 20221226, 'exception_type': 1}
# {'service_id': 'BFA22GEN-F048-Sunday-00', 'date': 20230102, 'exception_type': 1}
# {'service_id': 'BFA22GEN-F048-Sunday-00', 'date': 20230529, 'exception_type': 1}
# {'service_id': 'BFA22GEN-FS012-Sunday-00', 'date': 20221226, 'exception_type': 1}
# {'service_id': 'BFA22GEN-FS012-Sunday-00', 'date': 20230102, 'exception_type': 1}
# {'service_id': 'BFA22GEN-FS012-Sunday-00', 'date': 20230529, 'exception_type': 1}
# {'service_id': 'BFA22GEN-G037-Sunday-00', 'date': 20221226, 'exception_type': 1}
# {'service_id': 'BFA22GEN-G037-Sunday-00', 'date': 20230102, 'exception_type': 1}
# {'service_id': 'BFA22GEN-G037-Sunday-00', 'date': 20230529, 'exception_type': 1}
# {'service_id': 'AFA22GEN-GS013-Sunday-00', 'date': 20221226, 'exception_type': 1}
# {'service_id': 'AFA22GEN-GS013-Sunday-00', 'date': 20230102, 'exception_type': 1}
# {'service_id': 'AFA22GEN-GS013-Sunday-00', 'date': 20230529, 'exception_type': 1}
# {'service_id': 'BFA22GEN-H025-Sunday-00', 'date': 20221226, 'exception_type': 1}
# {'service_id': 'BFA22GEN-H025-Sunday-00', 'date': 20230102, 'exception_type': 1}
# {'service_id': 'BFA22GEN-H025-Sunday-00', 'date': 20230529, 'exception_type': 1}
# {'service_id': 'BFA22GEN-J032-Sunday-00', 'date': 20221226, 'exception_type': 1}
# {'service_id': 'BFA22GEN-J032-Sunday-00', 'date': 20230102, 'exception_type': 1}
# {'service_id': 'BFA22GEN-J032-Sunday-00', 'date': 20230529, 'exception_type': 1}
# {'service_id': 'BFA22GEN-L022-Sunday-00', 'date': 20221226, 'exception_type': 1}
# {'service_id': 'BFA22GEN-L022-Sunday-00', 'date': 20230102, 'exception_type': 1}
# {'service_id': 'BFA22GEN-L022-Sunday-00', 'date': 20230529, 'exception_type': 1}
# {'service_id': 'BFA22GEN-M023-Sunday-00', 'date': 20221226, 'exception_type': 1}
# {'service_id': 'BFA22GEN-M023-Sunday-00', 'date': 20230102, 'exception_type': 1}
# {'service_id': 'BFA22GEN-M023-Sunday-00', 'date': 20230529, 'exception_type': 1}
# {'service_id': 'BFA22GEN-N059-Sunday-00', 'date': 20221226, 'exception_type': 1}
# {'service_id': 'BFA22GEN-N059-Sunday-00', 'date': 20230102, 'exception_type': 1}
# {'service_id': 'BFA22GEN-N059-Sunday-00', 'date': 20230529, 'exception_type': 1}
# {'service_id': 'BFA22GEN-Q023-Sunday-00', 'date': 20221226, 'exception_type': 1}
# {'service_id': 'BFA22GEN-Q023-Sunday-00', 'date': 20230102, 'exception_type': 1}
# {'service_id': 'BFA22GEN-Q023-Sunday-00', 'date': 20230529, 'exception_type': 1}
# {'service_id': 'BFA22GEN-R050-Sunday-00', 'date': 20221226, 'exception_type': 1}
# {'service_id': 'BFA22GEN-R050-Sunday-00', 'date': 20230102, 'exception_type': 1}
# {'service_id': 'BFA22GEN-R050-Sunday-00', 'date': 20230529, 'exception_type': 1}
# {'service_id': 'AFA22GEN-1038-Saturday-00', 'date': 20230220, 'exception_type': 1}
# {'service_id': 'AFA22GEN-2042-Saturday-00', 'date': 20230220, 'exception_type': 1}
# {'service_id': 'AFA22GEN-3039-Saturday-00', 'date': 20230220, 'exception_type': 1}
# {'service_id': 'AFA22GEN-4043-Saturday-00', 'date': 20230220, 'exception_type': 1}
# {'service_id': 'AFA22GEN-5043-Saturday-00', 'date': 20230220, 'exception_type': 1}
# {'service_id': 'AFA22GEN-6033-Saturday-00', 'date': 20230220, 'exception_type': 1}
# {'service_id': 'AFA22GEN-7023-Saturday-00', 'date': 20230220, 'exception_type': 1}
# {'service_id': 'BFA22GEN-A046-Saturday-00', 'date': 20230220, 'exception_type': 1}
# {'service_id': 'BFA22GEN-C025-Saturday-00', 'date': 20230220, 'exception_type': 1}
# {'service_id': 'BFA22GEN-D039-Saturday-00', 'date': 20230220, 'exception_type': 1}
# {'service_id': 'BFA22GEN-E041-Saturday-00', 'date': 20230220, 'exception_type': 1}
# {'service_id': 'BFA22GEN-F044-Saturday-00', 'date': 20230220, 'exception_type': 1}
# {'service_id': 'BFA22GEN-FS011-Saturday-00', 'date': 20230220, 'exception_type': 1}
# {'service_id': 'BFA22GEN-G036-Saturday-00', 'date': 20230220, 'exception_type': 1}
# {'service_id': 'AFA22GEN-GS013-Saturday-00', 'date': 20230220, 'exception_type': 1}
# {'service_id': 'BFA22GEN-H026-Saturday-00', 'date': 20230220, 'exception_type': 1}
# {'service_id': 'BFA22GEN-J032-Saturday-00', 'date': 20230220, 'exception_type': 1}
# {'service_id': 'BFA22GEN-L022-Saturday-00', 'date': 20230220, 'exception_type': 1}
# {'service_id': 'BFA22GEN-M024-Saturday-00', 'date': 20230220, 'exception_type': 1}
# {'service_id': 'BFA22GEN-N056-Saturday-00', 'date': 20230220, 'exception_type': 1}
# {'service_id': 'BFA22GEN-Q021-Saturday-00', 'date': 20230220, 'exception_type': 1}
# {'service_id': 'BFA22GEN-R051-Saturday-00', 'date': 20230220, 'exception_type': 1}
# {'service_id': 'SIR-FA2017-SI017-Sunday-00', 'date': 20230102, 'exception_type': 1}
# {'service_id': 'SIR-FA2017-SI017-Sunday-00', 'date': 20230529, 'exception_type': 1}
# {'service_id': 'SIR-FA2017-SI017-Saturday-00', 'date': 20230220, 'exception_type': 1}

# %%
# Query calendar_result between configured dates
queried_calendar_result = calendar_result[(calendar_result['date'] >= SEARCH_FROM_DATE) & (calendar_result['date'] <= SEARCH_TO_DATE)]

# %%
# Save updated calendar dataframe to a new file
if not os.path.exists('results'):
    os.makedirs('results')
queried_calendar_result.to_csv(f'results/{SEARCH_FROM_DATE}_to_{SEARCH_TO_DATE}_route_schedule.csv', index=False)
