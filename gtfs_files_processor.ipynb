# %%
import pandas as pd
from datetime import datetime, timedelta
import os
import re

# %%
# Configuration
SEARCH_FROM_YEAR  = 2019
SEARCH_FROM_MONTH = 1
SEARCH_FROM_DAY   = 1

SEARCH_TO_YEAR  = 2019
SEARCH_TO_MONTH = 12
SEARCH_TO_DAY   = 31

SEARCH_FROM_DATE = SEARCH_FROM_YEAR*1000 + SEARCH_FROM_MONTH*100 + SEARCH_FROM_DAY
SEARCH_TO_DATE = SEARCH_TO_YEAR*1000 + SEARCH_TO_MONTH*100 + SEARCH_TO_DAY

# %%
folder_path = "./files/"
calendar_pattern = r"calendar_\d+.*\.txt"
calendar_dates_pattern = r"calendar_dates_\d+.*\.txt"

calendar_files = [f for f in os.listdir(folder_path) if re.match(calendar_pattern, f)]
calendar_dates_files = [f for f in os.listdir(folder_path) if re.match(calendar_dates_pattern, f)]

# %%
def process_calendar_file(calendar_file):
    # Read the calendar.txt file into a DataFrame
    calendar = pd.read_csv(calendar_file)

    # Convert the start_date and end_date columns to datetime objects
    calendar['start_date'] = pd.to_datetime(calendar['start_date'], format='%Y%m%d')
    calendar['end_date'] = pd.to_datetime(calendar['end_date'], format='%Y%m%d')

    # Generate a DataFrame with the service ID for each date
    dates = pd.DataFrame(columns=['date', 'service_id', 'gtfs_generation_date'])
    for _, row in calendar.iterrows():
        start_date = row['start_date']
        end_date = row['end_date']
        service_days = [int(x) for x in row[1:8]]
        service_id = row['service_id']
        for i in range((end_date - start_date).days + 1):
            date = start_date + timedelta(days=i)
            if service_days[date.weekday()] == 1:
                new_row = {'date': int(date.strftime('%Y%m%d')), 'service_id': service_id, 'gtfs_generation_date': calendar_file[17:25]}
                # date will be retrieved as a int64
                # new_row = {'date': date, 'service_id': service_id, 'gtfs_generation_date': calendar_file[17:25]}
                dates = pd.concat([dates, pd.DataFrame(new_row, index=[0])])

    return(dates)

# %%
def process_calendar_dates_file(calendar_date_file):
    # Read the calendar_dates.txt file into a DataFrame
    calendar_dates = pd.read_csv(calendar_date_file)

    return(calendar_dates)

# %%
df_calendar = pd.DataFrame()
df_calendar_dates = pd.DataFrame()
# Set the path to the GTFS files
for filename in calendar_files:
    calendar_file = folder_path + filename # example: calendar_20181221.txt'
    df_calendar = pd.concat([df_calendar, process_calendar_file(calendar_file)])

for filename in calendar_dates_files:
    calendar_dates_file = folder_path + filename # example: calendar_dates_20181221.txt'
    df_calendar_dates = pd.concat([df_calendar_dates, process_calendar_dates_file(calendar_dates_file)])

# %%
# Group the DataFrame by date, service_id
calendar_grouped = df_calendar.groupby(['date', 'service_id'])

# Use the apply method to filter the DataFrame and select the rows with the maximum gtfs_generation_date for each group
calendar_result = calendar_grouped.apply(lambda x: x[x['gtfs_generation_date'] == x['gtfs_generation_date'].max()])

# Reset the index of the result DataFrame
calendar_result = calendar_result.reset_index(drop=True)

# Select the columns of interest
calendar_result = calendar_result[['date', 'service_id', 'gtfs_generation_date']]

# Retrieve unique calendar dates from aggregation of calendar_dates.txt
calendar_dates_unique_rows = df_calendar_dates.drop_duplicates(subset=['date', 'service_id', 'exception_type'])

# %%
# Calendar dates exception types decodes
# 1 - Service has been added for the specified date.
# 2 - Service has been removed for the specified date.

# Iterate through calendar_dates dataframe and make appropriate chnge to calendar_result
for index, row in calendar_dates_unique_rows.iterrows():
    service_id = row['service_id']
    exception_type = row['exception_type']
    
    
    # If exception type is 1, add service for specified date
    if exception_type == 1:
        date = row['date']
        new_row = {'service_id': service_id, 'date': date, 'exception_type': exception_type}
        print(new_row)
        # calendar_result = calendar_result.append(new_row, ignore_index=True)
        calendar_result = pd.concat([calendar_result, pd.DataFrame(new_row, index=[0])])

    # If exception type is 2, remove service for specified date
    elif exception_type == 2:
        date = row['date']
        calendar_result = calendar_result[~((calendar_result['service_id'] == service_id) & (calendar_result['date'] == date))]

# Clean calendar_result
calendar_result.reset_index(drop=True)
calendar_result = calendar_result[['date','service_id']]

# sort the DataFrame by the date column in ascending order
calendar_result = calendar_result.sort_values(by=['date','service_id'])
# Out:
# {'service_id': 'AFA18GEN-1037-Sunday-00', 'date': 20181122, 'exception_type': 1}
# {'service_id': 'AFA18GEN-1037-Sunday-00', 'date': 20181225, 'exception_type': 1}
# {'service_id': 'AFA18GEN-1037-Sunday-00', 'date': 20190101, 'exception_type': 1}
# {'service_id': 'AFA18GEN-2048-Sunday-00', 'date': 20181122, 'exception_type': 1}
# {'service_id': 'AFA18GEN-2048-Sunday-00', 'date': 20181225, 'exception_type': 1}
# {'service_id': 'AFA18GEN-2048-Sunday-00', 'date': 20190101, 'exception_type': 1}
# {'service_id': 'AFA18GEN-3041-Sunday-00', 'date': 20181122, 'exception_type': 1}
# {'service_id': 'AFA18GEN-3041-Sunday-00', 'date': 20181225, 'exception_type': 1}
# {'service_id': 'AFA18GEN-3041-Sunday-00', 'date': 20190101, 'exception_type': 1}
# {'service_id': 'AFA18GEN-4049-Sunday-00', 'date': 20181122, 'exception_type': 1}
# {'service_id': 'AFA18GEN-4049-Sunday-00', 'date': 20181225, 'exception_type': 1}
# {'service_id': 'AFA18GEN-4049-Sunday-00', 'date': 20190101, 'exception_type': 1}
# {'service_id': 'AFA18GEN-5048-Sunday-00', 'date': 20181122, 'exception_type': 1}
# {'service_id': 'AFA18GEN-5048-Sunday-00', 'date': 20181225, 'exception_type': 1}
# {'service_id': 'AFA18GEN-5048-Sunday-00', 'date': 20190101, 'exception_type': 1}
# {'service_id': 'AFA18GEN-6030-Sunday-00', 'date': 20181122, 'exception_type': 1}
# {'service_id': 'AFA18GEN-6030-Sunday-00', 'date': 20181225, 'exception_type': 1}
# {'service_id': 'AFA18GEN-6030-Sunday-00', 'date': 20190101, 'exception_type': 1}
# {'service_id': 'AFA18GEN-7025-Sunday-00', 'date': 20181122, 'exception_type': 1}
# {'service_id': 'AFA18GEN-7025-Sunday-00', 'date': 20181225, 'exception_type': 1}
# {'service_id': 'AFA18GEN-7025-Sunday-00', 'date': 20190101, 'exception_type': 1}
# {'service_id': 'BFA18GEN-A051-Sunday-00', 'date': 20181122, 'exception_type': 1}
# {'service_id': 'BFA18GEN-A051-Sunday-00', 'date': 20181225, 'exception_type': 1}
# {'service_id': 'BFA18GEN-A051-Sunday-00', 'date': 20190101, 'exception_type': 1}
# {'service_id': 'BFA18GEN-C026-Sunday-00', 'date': 20181122, 'exception_type': 1}
# {'service_id': 'BFA18GEN-C026-Sunday-00', 'date': 20181225, 'exception_type': 1}
# {'service_id': 'BFA18GEN-C026-Sunday-00', 'date': 20190101, 'exception_type': 1}
# {'service_id': 'BFA18GEN-D040-Sunday-00', 'date': 20181122, 'exception_type': 1}
# {'service_id': 'BFA18GEN-D040-Sunday-00', 'date': 20181225, 'exception_type': 1}
# {'service_id': 'BFA18GEN-D040-Sunday-00', 'date': 20190101, 'exception_type': 1}
# {'service_id': 'BFA18GEN-E044-Sunday-00', 'date': 20181122, 'exception_type': 1}
# {'service_id': 'BFA18GEN-E044-Sunday-00', 'date': 20181225, 'exception_type': 1}
# {'service_id': 'BFA18GEN-E044-Sunday-00', 'date': 20190101, 'exception_type': 1}
# {'service_id': 'BFA18GEN-F048-Sunday-00', 'date': 20181122, 'exception_type': 1}
# {'service_id': 'BFA18GEN-F048-Sunday-00', 'date': 20181225, 'exception_type': 1}
# {'service_id': 'BFA18GEN-F048-Sunday-00', 'date': 20190101, 'exception_type': 1}
# {'service_id': 'BFA18GEN-FS012-Sunday-00', 'date': 20181122, 'exception_type': 1}
# {'service_id': 'BFA18GEN-FS012-Sunday-00', 'date': 20181225, 'exception_type': 1}
# {'service_id': 'BFA18GEN-FS012-Sunday-00', 'date': 20190101, 'exception_type': 1}
# {'service_id': 'BFA18GEN-G034-Sunday-00', 'date': 20181122, 'exception_type': 1}
# {'service_id': 'BFA18GEN-G034-Sunday-00', 'date': 20181225, 'exception_type': 1}
# {'service_id': 'BFA18GEN-G034-Sunday-00', 'date': 20190101, 'exception_type': 1}
# {'service_id': 'AFA18GEN-GS010-Sunday-00', 'date': 20181122, 'exception_type': 1}
# {'service_id': 'AFA18GEN-GS010-Sunday-00', 'date': 20181225, 'exception_type': 1}
# {'service_id': 'AFA18GEN-GS010-Sunday-00', 'date': 20190101, 'exception_type': 1}
# {'service_id': 'BFA18GEN-H024-Sunday-00', 'date': 20181122, 'exception_type': 1}
# {'service_id': 'BFA18GEN-H024-Sunday-00', 'date': 20181225, 'exception_type': 1}
# {'service_id': 'BFA18GEN-H024-Sunday-00', 'date': 20190101, 'exception_type': 1}
# {'service_id': 'BFA18GEN-J032-Sunday-00', 'date': 20181122, 'exception_type': 1}
# {'service_id': 'BFA18GEN-J032-Sunday-00', 'date': 20181225, 'exception_type': 1}
# {'service_id': 'BFA18GEN-J032-Sunday-00', 'date': 20190101, 'exception_type': 1}
# {'service_id': 'BFA18GEN-L022-Sunday-00', 'date': 20181122, 'exception_type': 1}
# {'service_id': 'BFA18GEN-L022-Sunday-00', 'date': 20181225, 'exception_type': 1}
# {'service_id': 'BFA18GEN-L022-Sunday-00', 'date': 20190101, 'exception_type': 1}
# {'service_id': 'BFA18GEN-M023-Sunday-00', 'date': 20181122, 'exception_type': 1}
# {'service_id': 'BFA18GEN-M023-Sunday-00', 'date': 20181225, 'exception_type': 1}
# {'service_id': 'BFA18GEN-M023-Sunday-00', 'date': 20190101, 'exception_type': 1}
# {'service_id': 'BFA18GEN-N057-Sunday-00', 'date': 20181122, 'exception_type': 1}
# {'service_id': 'BFA18GEN-N057-Sunday-00', 'date': 20181225, 'exception_type': 1}
# {'service_id': 'BFA18GEN-N057-Sunday-00', 'date': 20190101, 'exception_type': 1}
# {'service_id': 'BFA18GEN-Q022-Sunday-00', 'date': 20181122, 'exception_type': 1}
# {'service_id': 'BFA18GEN-Q022-Sunday-00', 'date': 20181225, 'exception_type': 1}
# {'service_id': 'BFA18GEN-Q022-Sunday-00', 'date': 20190101, 'exception_type': 1}
# {'service_id': 'BFA18GEN-R049-Sunday-00', 'date': 20181122, 'exception_type': 1}
# {'service_id': 'BFA18GEN-R049-Sunday-00', 'date': 20181225, 'exception_type': 1}
# {'service_id': 'BFA18GEN-R049-Sunday-00', 'date': 20190101, 'exception_type': 1}
# {'service_id': 'SIR-FA2018-SI017-Sunday-00', 'date': 20181122, 'exception_type': 1}
# {'service_id': 'SIR-FA2018-SI017-Sunday-00', 'date': 20181225, 'exception_type': 1}
# {'service_id': 'SIR-FA2018-SI017-Sunday-00', 'date': 20190101, 'exception_type': 1}
# {'service_id': 'AFA18GEN-1038-Saturday-00', 'date': 20190218, 'exception_type': 1}
# {'service_id': 'AFA18GEN-2042-Saturday-00', 'date': 20190218, 'exception_type': 1}
# {'service_id': 'AFA18GEN-3039-Saturday-00', 'date': 20190218, 'exception_type': 1}
# {'service_id': 'AFA18GEN-4043-Saturday-00', 'date': 20190218, 'exception_type': 1}
# {'service_id': 'AFA18GEN-5043-Saturday-00', 'date': 20190218, 'exception_type': 1}
# {'service_id': 'AFA18GEN-6033-Saturday-00', 'date': 20190218, 'exception_type': 1}
# {'service_id': 'AFA18GEN-7023-Saturday-00', 'date': 20190218, 'exception_type': 1}
# {'service_id': 'BFA18GEN-A044-Saturday-00', 'date': 20190218, 'exception_type': 1}
# {'service_id': 'BFA18GEN-C024-Saturday-00', 'date': 20190218, 'exception_type': 1}
# {'service_id': 'BFA18GEN-D037-Saturday-00', 'date': 20190218, 'exception_type': 1}
# {'service_id': 'BFA18GEN-E039-Saturday-00', 'date': 20190218, 'exception_type': 1}
# {'service_id': 'BFA18GEN-F044-Saturday-00', 'date': 20190218, 'exception_type': 1}
# {'service_id': 'BFA18GEN-FS011-Saturday-00', 'date': 20190218, 'exception_type': 1}
# {'service_id': 'BFA18GEN-G033-Saturday-00', 'date': 20190218, 'exception_type': 1}
# {'service_id': 'AFA18GEN-GS010-Saturday-00', 'date': 20190218, 'exception_type': 1}
# {'service_id': 'BFA18GEN-H024-Saturday-00', 'date': 20190218, 'exception_type': 1}
# {'service_id': 'BFA18GEN-J032-Saturday-00', 'date': 20190218, 'exception_type': 1}
# {'service_id': 'BFA18GEN-L022-Saturday-00', 'date': 20190218, 'exception_type': 1}
# {'service_id': 'BFA18GEN-M024-Saturday-00', 'date': 20190218, 'exception_type': 1}
# {'service_id': 'BFA18GEN-N054-Saturday-00', 'date': 20190218, 'exception_type': 1}
# {'service_id': 'BFA18GEN-Q020-Saturday-00', 'date': 20190218, 'exception_type': 1}
# {'service_id': 
Sunday-00', 'date': 20200101, 'exception_type': 1}
# {'service_id': 'AFA19GEN-2048-Sunday-00', 'date': 20191128, 'exception_type': 1}
# {'service_id': 'AFA19GEN-2048-Sunday-00', 'date': 20191225, 'exception_type': 1}
# {'service_id': 'AFA19GEN-2048-Sunday-00', 'date': 20200101, 'exception_type': 1}
# {'service_id': 'AFA19GEN-3041-Sunday-00', 'date': 20191128, 'exception_type': 1}
# {'service_id': 'AFA19GEN-3041-Sunday-00', 'date': 20191225, 'exception_type': 1}
# {'service_id': 'AFA19GEN-3041-Sunday-00', 'date': 20200101, 'exception_type': 1}
# {'service_id': 'AFA19GEN-4049-Sunday-00', 'date': 20191128, 'exception_type': 1}
# {'service_id': 'AFA19GEN-4049-Sunday-00', 'date': 20191225, 'exception_type': 1}
# {'service_id': 'AFA19GEN-4049-Sunday-00', 'date': 20200101, 'exception_type': 1}
# {'service_id': 'AFA19GEN-5048-Sunday-00', 'date': 20191128, 'exception_type': 1}
# {'service_id': 'AFA19GEN-5048-Sunday-00', 'date': 20191225, 'exception_type': 1}
# {'service_id': 'AFA19GEN-5048-Sunday-00', 'date': 20200101, 'exception_type': 1}
# {'service_id': 'AFA19GEN-6030-Sunday-00', 'date': 20191128, 'exception_type': 1}
# {'service_id': 'AFA19GEN-6030-Sunday-00', 'date': 20191225, 'exception_type': 1}
# {'service_id': 'AFA19GEN-6030-Sunday-00', 'date': 20200101, 'exception_type': 1}
# {'service_id': 'AFA19GEN-7025-Sunday-00', 'date': 20191128, 'exception_type': 1}
# {'service_id': 'AFA19GEN-7025-Sunday-00', 'date': 20191225, 'exception_type': 1}
# {'service_id': 'AFA19GEN-7025-Sunday-00', 'date': 20200101, 'exception_type': 1}
# {'service_id': 'BFA19GEN-A052-Sunday-00', 'date': 20191128, 'exception_type': 1}
# {'service_id': 'BFA19GEN-A052-Sunday-00', 'date': 20191225, 'exception_type': 1}
# {'service_id': 'BFA19GEN-A052-Sunday-00', 'date': 20200101, 'exception_type': 1}
# {'service_id': 'BFA19GEN-C027-Sunday-00', 'date': 20191128, 'exception_type': 1}
# {'service_id': 'BFA19GEN-C027-Sunday-00', 'date': 20191225, 'exception_type': 1}
# {'service_id': 'BFA19GEN-C027-Sunday-00', 'date': 20200101, 'exception_type': 1}
# {'service_id': 'BFA19GEN-D040-Sunday-00', 'date': 20191128, 'exception_type': 1}
# {'service_id': 'BFA19GEN-D040-Sunday-00', 'date': 20191225, 'exception_type': 1}
# {'service_id': 'BFA19GEN-D040-Sunday-00', 'date': 20200101, 'exception_type': 1}
# {'service_id': 'BFA19GEN-E046-Sunday-00', 'date': 20191128, 'exception_type': 1}
# {'service_id': 'BFA19GEN-E046-Sunday-00', 'date': 20191225, 'exception_type': 1}
# {'service_id': 'BFA19GEN-E046-Sunday-00', 'date': 20200101, 'exception_type': 1}
# {'service_id': 'BFA19GEN-F048-Sunday-00', 'date': 20191128, 'exception_type': 1}
# {'service_id': 'BFA19GEN-F048-Sunday-00', 'date': 20191225, 'exception_type': 1}
# {'service_id': 'BFA19GEN-F048-Sunday-00', 'date': 20200101, 'exception_type': 1}
# {'service_id': 'BFA19GEN-FS012-Sunday-00', 'date': 20191128, 'exception_type': 1}
# {'service_id': 'BFA19GEN-FS012-Sunday-00', 'date': 20191225, 'exception_type': 1}
# {'service_id': 'BFA19GEN-FS012-Sunday-00', 'date': 20200101, 'exception_type': 1}
# {'service_id': 'BFA19GEN-G036-Sunday-00', 'date': 20191128, 'exception_type': 1}
# {'service_id': 'BFA19GEN-G036-Sunday-00', 'date': 20191225, 'exception_type': 1}
# {'service_id': 'BFA19GEN-G036-Sunday-00', 'date': 20200101, 'exception_type': 1}
# {'service_id': 'AFA19GEN-GS010-Sunday-00', 'date': 20191128, 'exception_type': 1}
# {'service_id': 'AFA19GEN-GS010-Sunday-00', 'date': 20191225, 'exception_type': 1}
# {'service_id': 'AFA19GEN-GS010-Sunday-00', 'date': 20200101, 'exception_type': 1}
# {'service_id': 'BFA19GEN-H024-Sunday-00', 'date': 20191128, 'exception_type': 1}
# {'service_id': 'BFA19GEN-H024-Sunday-00', 'date': 20191225, 'exception_type': 1}
# {'service_id': 'BFA19GEN-H024-Sunday-00', 'date': 20200101, 'exception_type': 1}
# {'service_id': 'BFA19GEN-J032-Sunday-00', 'date': 20191128, 'exception_type': 1}
# {'service_id': 'BFA19GEN-J032-Sunday-00', 'date': 20191225, 'exception_type': 1}
# {'service_id': 'BFA19GEN-J032-Sunday-00', 'date': 20200101, 'exception_type': 1}
# {'service_id': 'BFA19SUPP-L024-Sunday-99', 'date': 20191128, 'exception_type': 1}
# {'service_id': 'BFA19SUPP-L024-Sunday-99', 'date': 20191225, 'exception_type': 1}
# {'service_id': 'BFA19SUPP-L024-Sunday-99', 'date': 20200101, 'exception_type': 1}
# {'service_id': 'BFA19GEN-M026-Sunday-00', 'date': 20191128, 'exception_type': 1}
# {'service_id': 'BFA19GEN-M026-Sunday-00', 'date': 20191225, 'exception_type': 1}
# {'service_id': 'BFA19GEN-M026-Sunday-00', 'date': 20200101, 'exception_type': 1}
# {'service_id': 'BFA19GEN-N058-Sunday-00', 'date': 20191128, 'exception_type': 1}
# {'service_id': 'BFA19GEN-N058-Sunday-00', 'date': 20191225, 'exception_type': 1}
# {'service_id': 'BFA19GEN-N058-Sunday-00', 'date': 20200101, 'exception_type': 1}
# {'service_id': 'BFA19GEN-Q023-Sunday-00', 'date': 20191128, 'exception_type': 1}
# {'service_id': 'BFA19GEN-Q023-Sunday-00', 'date': 20191225, 'exception_type': 1}
# {'service_id': 'BFA19GEN-Q023-Sunday-00', 'date': 20200101, 'exception_type': 1}
# {'service_id': 'BFA19GEN-R050-Sunday-00', 'date': 20191128, 'exception_type': 1}
# {'service_id': 'BFA19GEN-R050-Sunday-00', 'date': 20191225, 'exception_type': 1}
# {'service_id': 'BFA19GEN-R050-Sunday-00', 'date': 20200101, 'exception_type': 1}
# {'service_id': 'SIR-FA2017-SI017-Sunday-00', 'date': 20191128, 'exception_type': 1}
# {'service_id': 'SIR-FA2017-SI017-Sunday-00', 'date': 20191225, 'exception_type': 1}
# {'service_id': 'SIR-FA2017-SI017-Sunday-00', 'date': 20200101, 'exception_type': 1}
# {'service_id': 'AFA19GEN-1038-Saturday-00', 'date': 20200217, 'exception_type': 1}
# {'service_id': 'AFA19GEN-2042-Saturday-00', 'date': 20200217, 'exception_type': 1}
# {'service_id': 'AFA19GEN-3039-Saturday-00', 'date': 20200217, 'exception_type': 1}
# {'service_id': 'AFA19GEN-4043-Saturday-00', 'date': 20200217, 'exception_type': 1}
# {'service_id': 'AFA19GEN-5043-Saturday-00', 'date': 20200217, 'exception_type': 1}
# {'service_id': 'AFA19GEN-6033-Saturday-00', 'date': 20200217, 'exception_type': 1}
# {'service_id': 'AFA19GEN-7023-Saturday-00', 'date': 20200217, 'exception_type': 1}
# {'service_id': 'BFA19GEN-A045-Saturday-00', 'date': 20200217, 'exception_type': 1}
# {'service_id': 'BFA19GEN-C025-Saturday-00', 'date': 20200217, 'exception_type': 1}
# {'service_id': 'BFA19GEN-D037-Saturday-00', 'date': 20200217, 'exception_type': 1}
# {'service_id': 'BFA19GEN-E041-Saturday-00', 'date': 20200217, 'exception_type': 1}
# {'service_id': 'BFA19GEN-F044-Saturday-00', 'date': 20200217, 'exception_type': 1}
# {'service_id': 'BFA19GEN-FS011-Saturday-00', 'date': 20200217, 'exception_type': 1}
# {'service_id': 'BFA19GEN-G035-Saturday-00', 'date': 20200217, 'exception_type': 1}
# {'service_id': 'AFA19GEN-GS010-Saturday-00', 'date': 20200217, 'exception_type': 1}
# {'service_id': 'BFA19GEN-H025-Saturday-00', 'date': 20200217, 'exception_type': 1}
# {'service_id': 'BFA19GEN-J032-Saturday-00', 'date': 20200217, 'exception_type': 1}
# {'service_id': 'BFA19SUPP-L024-Saturday-99', 'date': 20200217, 'exception_type': 1}
# {'service_id': 'BFA19GEN-M027-Saturday-00', 'date': 20200217, 'exception_type': 1}
# {'service_id': 'BFA19GEN-N055-Saturday-00', 'date': 20200217, 'exception_type': 1}
# {'service_id': 'BFA19GEN-Q021-Saturday-00', 'date': 20200217, 'exception_type': 1}
# {'service_id': 'BFA19GEN-R051-Saturday-00', 'date': 20200217, 'exception_type': 1}
# {'service_id': 'SIR-FA2017-SI017-Saturday-00', 'date': 20200217, 'exception_type': 1}

# %%
# Query calendar_result between configured dates
calendar_result = calendar_result[(calendar_result['value'] >= SEARCH_FROM_DATE) & (calendar_result['value'] <= SEARCH_TO_DATE)]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\cjong\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# c:\Users\cjong\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# c:\Users\cjong\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'value'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_26708\663841487.py in <module>
#       1 # Query calendar_result between configured dates
# ----> 2 calendar_result = calendar_result[(calendar_result['value'] >= SEARCH_FROM_DATE) & (calendar_result['value'] <= SEARCH_TO_DATE)]
#
# c:\Users\cjong\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3503             if self.columns.nlevels > 1:
#    3504                 return self._getitem_multilevel(key)
# -> 3505             indexer = self.columns.get_loc(key)
#    3506             if is_integer(indexer):
#    3507                 indexer = [indexer]
#
# c:\Users\cjong\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
# -> 3631                 raise KeyError(key) from err
#    3632             except TypeError:
#    3633                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'value'

# %%
# Save updated calendar dataframe to a new file
calendar_result.to_csv('updated_calendar.csv', index=False)
