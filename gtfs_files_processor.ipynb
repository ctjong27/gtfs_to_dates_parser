# %%
import pandas as pd
from datetime import datetime, timedelta
import os
import re

# %%
# Configuration
SEARCH_FROM_YEAR  = 2019
SEARCH_FROM_MONTH = 1
SEARCH_FROM_DAY   = 1

SEARCH_TO_YEAR  = 2019
SEARCH_TO_MONTH = 12
SEARCH_TO_DAY   = 31

SEARCH_FROM_DATE = SEARCH_FROM_YEAR*1000 + SEARCH_FROM_MONTH*100 + SEARCH_FROM_DAY
SEARCH_TO_DATE = SEARCH_TO_YEAR*1000 + SEARCH_TO_MONTH*100 + SEARCH_TO_DAY

# %%
folder_path = "./files/"
calendar_pattern = r"calendar_\d+.*\.txt"
calendar_dates_pattern = r"calendar_dates_\d+.*\.txt"

calendar_files = [f for f in os.listdir(folder_path) if re.match(calendar_pattern, f)]
calendar_dates_files = [f for f in os.listdir(folder_path) if re.match(calendar_dates_pattern, f)]

# %%
def process_calendar_file(calendar_file):
    # Read the calendar.txt file into a DataFrame
    calendar = pd.read_csv(calendar_file)

    # Convert the start_date and end_date columns to datetime objects
    calendar['start_date'] = pd.to_datetime(calendar['start_date'], format='%Y%m%d')
    calendar['end_date'] = pd.to_datetime(calendar['end_date'], format='%Y%m%d')

    # Generate a DataFrame with the service ID for each date
    dates = pd.DataFrame(columns=['date', 'service_id', 'gtfs_generation_date'])
    for _, row in calendar.iterrows():
        start_date = row['start_date']
        end_date = row['end_date']
        service_days = [int(x) for x in row[1:8]]
        service_id = row['service_id']
        for i in range((end_date - start_date).days + 1):
            date = start_date + timedelta(days=i)
            if service_days[date.weekday()] == 1:
                new_row = {'date': int(date.strftime('%Y%m%d')), 'service_id': service_id, 'gtfs_generation_date': calendar_file[17:25]}
                # date will be retrieved as a int64
                # new_row = {'date': date, 'service_id': service_id, 'gtfs_generation_date': calendar_file[17:25]}
                dates = pd.concat([dates, pd.DataFrame(new_row, index=[0])])

    return(dates)

# %%
def process_calendar_dates_file(calendar_date_file):
    # Read the calendar_dates.txt file into a DataFrame
    calendar_dates = pd.read_csv(calendar_date_file)

    return(calendar_dates)

# %%
df_calendar = pd.DataFrame()
df_calendar_dates = pd.DataFrame()
# Set the path to the GTFS files
for filename in calendar_files:
    calendar_file = folder_path + filename # example: calendar_20181221.txt'
    df_calendar = pd.concat([df_calendar, process_calendar_file(calendar_file)])

for filename in calendar_dates_files:
    calendar_dates_file = folder_path + filename # example: calendar_dates_20181221.txt'
    df_calendar_dates = pd.concat([df_calendar_dates, process_calendar_dates_file(calendar_dates_file)])

# %%
# Group the DataFrame by date, service_id
calendar_grouped = df_calendar.groupby(['date', 'service_id'])

# Use the apply method to filter the DataFrame and select the rows with the maximum gtfs_generation_date for each group
calendar_result = calendar_grouped.apply(lambda x: x[x['gtfs_generation_date'] == x['gtfs_generation_date'].max()])

# Reset the index of the result DataFrame
calendar_result = calendar_result.reset_index(drop=True)

# Select the columns of interest
calendar_result = calendar_result[['date', 'service_id', 'gtfs_generation_date']]

# Retrieve unique calendar dates from aggregation of calendar_dates.txt
calendar_dates_unique_rows = df_calendar_dates.drop_duplicates(subset=['date', 'service_id', 'exception_type'])

# %%
# Calendar dates exception types decodes
# 1 - Service has been added for the specified date.
# 2 - Service has been removed for the specified date.

# Iterate through calendar_dates dataframe and make appropriate chnge to calendar_result
for index, row in calendar_dates_unique_rows.iterrows():
    service_id = row['service_id']
    exception_type = row['exception_type']
    
    
    # If exception type is 1, add service for specified date
    if exception_type == 1:
        date = row['date']
        new_row = {'service_id': service_id, 'date': date, 'exception_type': exception_type}
        print(new_row)
        # calendar_result = calendar_result.append(new_row, ignore_index=True)
        calendar_result = pd.concat([calendar_result, pd.DataFrame(new_row, index=[0])])

    # If exception type is 2, remove service for specified date
    elif exception_type == 2:
        date = row['date']
        calendar_result = calendar_result[~((calendar_result['service_id'] == service_id) & (calendar_result['date'] == date))]

# Clean calendar_result
calendar_result.reset_index(drop=True)
calendar_result = calendar_result[['date','service_id']]

# sort the DataFrame by the date column in ascending order
calendar_result = calendar_result.sort_values(by=['date','service_id'])
# Out:
# service_id        AFA18GEN-1087-Weekday-00
# date                              20181122
# exception_type                           2
# Name: 69, dtype: object
#          date                service_id gtfs_generation_date
# 457  20181122  AFA18GEN-1087-Weekday-00             20190420
# service_id        AFA18GEN-1087-Weekday-00
# date                              20181225
# exception_type                           2
# Name: 70, dtype: object
#           date                service_id gtfs_generation_date
# 1293  20181225  AFA18GEN-1087-Weekday-00             20190420
# service_id        AFA18GEN-1087-Weekday-00
# date                              20190101
# exception_type                           2
# Name: 71, dtype: object
#           date                service_id gtfs_generation_date
# 1471  20190101  AFA18GEN-1087-Weekday-00             20190420
# service_id        AFA18GEN-1087-Weekday-00
# date                              20190218
# exception_type                           2
# Name: 72, dtype: object
#           date                service_id gtfs_generation_date
# 2693  20190218  AFA18GEN-1087-Weekday-00             20190420
# service_id        AFA18GEN-2097-Weekday-00
# date                              20181122
# exception_type                           2
# Name: 73, dtype: object
#          date                service_id gtfs_generation_date
# 458  20181122  AFA18GEN-2097-Weekday-00             20190420
# service_id        AFA18GEN-2097-Weekday-00
# date                              20181225
# exception_type                           2
# Name: 74, dtype: object
#           date                service_id gtfs_generation_date
# 1294  20181225  AFA18GEN-2097-Weekday-00             20190420
# service_id        AFA18GEN-2097-Weekday-00
# date                              20190101
# exception_type                           2
# Name: 75, dtype: object
#           date                service_id gtfs_generation_date
# 1472  20190101  AFA18GEN-2097-Weekday-00             20190420
# service_id        AFA18GEN-2097-Weekday-00
# date                              20190218
# exception_type                           2
# Name: 76, dtype: object
#           date                service_id gtfs_generation_date
# 2694  20190218  AFA18GEN-2097-Weekday-00             20190420
# service_id        AFA18GEN-3086-Weekday-00
# date                              20181122
# exception_type                           2
# Name: 77, dtype: object
#          date                service_id gtfs_generation_date
# 459  20181122  AFA18GEN-3086-Weekday-00             20190420
# service_id        AFA18GEN-3086-Weekday-00
# date                              20181225
# exception_type                           2
# Name: 78, dtype: object
#           date                service_id gtfs_generation_date
# 1295  20181225  AFA18GEN-3086-Weekday-00             20190420
# service_id        AFA18GEN-3086-Weekday-00
# date                              20190101
# exception_type                           2
# Name: 79, dtype: object
#           date                service_id gtfs_generation_date
# 1473  20190101  AFA18GEN-3086-Weekday-00             20190420
# service_id        AFA18GEN-3086-Weekday-00
# date                              20190218
# exception_type                           2
# Name: 80, dtype: object
#           date                service_id gtfs_generation_date
# 2695  20190218  AFA18GEN-3086-Weekday-00             20190420
# service_id        AFA18GEN-4097-Weekday-00
# date                              20181122
# exception_type                           2
# Name: 81, dtype: object
#          date                service_id gtfs_generation_date
# 460  20181122  AFA18GEN-4097-Weekday-00             20190420
# service_id        AFA18GEN-4097-Weekday-00
# date                              20181225
# exception_type                           2
# Name: 82, dtype: object
#           date                service_id gtfs_generation_date
# 1296  20181225  AFA18GEN-4097-Weekday-00             20190420
# service_id        AFA18GEN-4097-Weekday-00
# date                              20190101
# exception_type                           2
# Name: 83, dtype: object
#           date                service_id gtfs_generation_date
# 1474  20190101  AFA18GEN-4097-Weekday-00             20190420
# service_id        AFA18GEN-4097-Weekday-00
# date                              20190218
# exception_type                           2
# Name: 84, dtype: object
#           date                service_id gtfs_generation_date
# 2696  20190218  AFA18GEN-4097-Weekday-00             20190420
# service_id        AFA18GEN-5106-Weekday-00
# date                              20181122
# exception_type                           2
# Name: 85, dtype: object
#          date                service_id gtfs_generation_date
# 461  20181122  AFA18GEN-5106-Weekday-00             20190420
# service_id        AFA18GEN-5106-Weekday-00
# date                              20181225
# exception_type                           2
# Name: 86, dtype: object
#           date                service_id gtfs_generation_date
# 1297  20181225  AFA18GEN-5106-Weekday-00             20190420
# service_id        AFA18GEN-5106-Weekday-00
# date                              20190101
# exception_type                           2
# Name: 87, dtype: object
#           date                service_id gtfs_generation_date
# 1475  20190101  AFA18GEN-5106-Weekday-00             20190420
# service_id        AFA18GEN-5106-Weekday-00
# date                              20190218
# exception_type                           2
# Name: 88, dtype: object
#           date                service_id gtfs_generation_date
# 2697  20190218  AFA18GEN-5106-Weekday-00             20190420
# service_id        AFA18GEN-6085-Weekday-00
# date                              20181122
# exception_type                           2
# Name: 89, dtype: object
#          date                service_id gtfs_generation_date
# 462  20181122  AFA18GEN-6085-Weekday-00             20190420
# service_id        AFA18GEN-6085-Weekday-00
# date                              20181225
# exception_type                           2
# Name: 90, dtype: object
#           date                service_id gtfs_generation_date
# 1298  20181225  AFA18GEN-6085-Weekday-00             20190420
# service_id        AFA18GEN-6085-Weekday-00
# date                              20190101
# exception_type                           2
# Name: 91, dtype: object
#           date                service_id gtfs_generation_date
# 1476  20190101  AFA18GEN-6085-Weekday-00             20190420
# service_id        AFA18GEN-6085-Weekday-00
# date                              20190218
# exception_type                           2
# Name: 92, dtype: object
#           date                service_id gtfs_generation_date
# 2698  20190218  AFA18GEN-6085-Weekday-00             20190420
# service_id        AFA18GEN-7058-Weekday-00
# date                              20181122
# exception_type                           2
# Name: 93, dtype: object
#          date                service_id gtfs_generation_date
# 463  20181122  AFA18GEN-7058-Weekday-00             20190420
# service_id        AFA18GEN-7058-Weekday-00
# date                              20181225
# exception_type                           2
# Name: 94, dtype: object
#           date                service_id gtfs_generation_date
# 1299  20181225  AFA18GEN-7058-Weekday-00             20190420
# service_id        AFA18GEN-7058-Weekday-00
# date                              20190101
# exception_type                           2
# Name: 95, dtype: object
#           date                service_id gtfs_generation_date
# 1477  20190101  AFA18GEN-7058-Weekday-00             20190420
# service_id        AFA18GEN-7058-Weekday-00
# date                              20190218
# exception_type                           2
# Name: 96, dtype: object
#           date                service_id gtfs_generation_date
# 2699  20190218  AFA18GEN-7058-Weekday-00             20190420
# service_id        BFA18GEN-A083-Weekday-00
# date                              20181122
# exception_type                           2
# Name: 97, dtype: object
#          date                service_id gtfs_generation_date
# 465  20181122  BFA18GEN-A083-Weekday-00             20190420
# service_id        BFA18GEN-A083-Weekday-00
# date                              20181225
# exception_type                           2
# Name: 98, dtype: object
#           date                service_id gtfs_generation_date
# 1301  20181225  BFA18GEN-A083-Weekday-00             20190420
# service_id        BFA18GEN-A083-Weekday-00
# date                              20190101
# exception_type                           2
# Name: 99, dtype: object
#           date                service_id gtfs_generation_date
# 1479  20190101  BFA18GEN-A083-Weekday-00             20190420
# service_id        BFA18GEN-A083-Weekday-00
# date                              20190218
# exception_type                           2
# Name: 100, dtype: object
#           date                service_id gtfs_generation_date
# 2701  20190218  BFA18GEN-A083-Weekday-00             20190420
# service_id        BFA18GEN-B080-Weekday-00
# date                              20181225
# exception_type                           2
# Name: 101, dtype: object
#           date                service_id gtfs_generation_date
# 1302  20181225  BFA18GEN-B080-Weekday-00             20190420
# service_id        BFA18GEN-B080-Weekday-00
# date                              20190101
# exception_type                           2
# Name: 102, dtype: object
#           date                service_id gtfs_generation_date
# 1480  20190101  BFA18GEN-B080-Weekday-00             20190420
# service_id        BFA18GEN-B080-Weekday-00
# date                              20190218
# exception_type                           2
# Name: 103, dtype: object
#           date                service_id gtfs_generation_date
# 2702  20190218  BFA18GEN-B080-Weekday-00             20190420
# service_id        BFA18GEN-C049-Weekday-00
# date                              20181122
# exception_type                           2
# Name: 104, dtype: object
#          date                service_id gtfs_generation_date
# 467  20181122  BFA18GEN-C049-Weekday-00             20190420
# service_id        BFA18GEN-C049-Weekday-00
# date                              20181225
# exception_type                           2
# Name: 105, dtype: object
#           date                service_id gtfs_generation_date
# 1303  20181225  BFA18GEN-C049-Weekday-00             20190420
# service_id        BFA18GEN-C049-Weekday-00
# date                              20190101
# exception_type                           2
# Name: 106, dtype: object
#           date                service_id gtfs_generation_date
# 1481  20190101  BFA18GEN-C049-Weekday-00             20190420
# service_id        BFA18GEN-C049-Weekday-00
# date                              20190218
# exception_type                           2
# Name: 107, dtype: object
#           date                service_id gtfs_generation_date
# 2703  20190218  BFA18GEN-C049-Weekday-00             20190420
# service_id        BFA18GEN-D077-Weekday-00
# date                              20181122
# exception_type                           2
# Name: 108, dtype: object
#          date                service_id gtfs_generation_date
# 468  20181122  BFA18GEN-D077-Weekday-00             20190420
# service_id        BFA18GEN-D077-Weekday-00
# date                              20181225
# exception_type                           2
# Name: 109, dtype: object
#           date                service_id gtfs_generation_date
# 1304  20181225  BFA18GEN-D077-Weekday-00             20190420
# service_id        BFA18GEN-D077-Weekday-00
# date                              20190101
# exception_type                           2
# Name: 110, dtype: object
#           date                service_id gtfs_generation_date
# 1482  20190101  BFA18GEN-D077-Weekday-00             20190420
# service_id        BFA18GEN-D077-Weekday-00
# date                              20190218
# exception_type                           2
# Name: 111, dtype: object
#           date                service_id gtfs_generation_date
# 2704  20190218  BFA18GEN-D077-Weekday-00             20190420
# service_id        BFA18GEN-E071-Weekday-00
# date                              20181122
# exception_type                           2
# Name: 112, dtype: object
#          date                service_id gtfs_generation_date
# 469  20181122  BFA18GEN-E071-Weekday-00             20190420
# service_id        BFA18GEN-E071-Weekday-00
# date                              20181225
# exception_type                           2
# Name: 113, dtype: object
#           date                service_id gtfs_generation_date
# 1305  20181225  BFA18GEN-E071-Weekday-00             20190420
# service_id        BFA18GEN-E071-Weekday-00
# date                              20190101
# exception_type                           2
# Name: 114, dtype: object
#           date                service_id gtfs_generation_date
# 1483  20190101  BFA18GEN-E071-Weekday-00             20190420
# service_id        BFA18GEN-E071-Weekday-00
# date                              20190218
# exception_type                           2
# Name: 115, dtype: object
#           date                service_id gtfs_generation_date
# 2705  20190218  BFA18GEN-E071-Weekday-00             20190420
# service_id        BFA18GEN-F072-Weekday-00
# date                              20181122
# exception_type                           2
# Name: 116, dtype: object
#          date                service_id gtfs_generation_date
# 470  20181122  BFA18GEN-F072-Weekday-00             20190420
# service_id        BFA18GEN-F072-Weekday-00
# date                              20181225
# exception_type                           2
# Name: 117, dtype: object
#           date                service_id gtfs_generation_date
# 1306  20181225  BFA18GEN-F072-Weekday-00             20190420
# service_id        BFA18GEN-F072-Weekday-00
# date                              20190101
# exception_type                           2
# Name: 118, dtype: object
#           date                service_id gtfs_generation_date
# 1484  20190101  BFA18GEN-F072-Weekday-00             20190420
# service_id        BFA18GEN-F072-Weekday-00
# date                              20190218
# exception_type                           2
# Name: 119, dtype: object
#           date                service_id gtfs_generation_date
# 2706  20190218  BFA18GEN-F072-Weekday-00             20190420
# service_id        BFA18GEN-FS011-Weekday-00
# date                               20181122
# exception_type                            2
# Name: 120, dtype: object
#          date                 service_id gtfs_generation_date
# 471  20181122  BFA18GEN-FS011-Weekday-00             20190420
# service_id        BFA18GEN-FS011-Weekday-00
# date                               20181225
# exception_type                            2
# Name: 121, dtype: object
#           date                 service_id gtfs_generation_date
# 1307  20181225  BFA18GEN-FS011-Weekday-00             20190420
# service_id        BFA18GEN-FS011-Weekday-00
# date                               20190101
# exception_type                            2
# Name: 122, dtype: object
#           date                 service_id gtfs_generation_date
# 1485  20190101  BFA18GEN-FS011-Weekday-00             20190420
# service_id        BFA18GEN-FS011-Weekday-00
# date                               20190218
# exception_type                            2
# Name: 123, dtype: object
#           date                 service_id gtfs_generation_date
# 2707  20190218  BFA18GEN-FS011-Weekday-00             20190420
# service_id        BFA18GEN-G049-Weekday-00
# date                              20181122
# exception_type                           2
# Name: 124, dtype: object
#          date                service_id gtfs_generation_date
# 472  20181122  BFA18GEN-G049-Weekday-00             20190420
# service_id        BFA18GEN-G049-Weekday-00-0111100
# date                                      20181122
# exception_type                                   2
# Name: 125, dtype: object
#          date                        service_id gtfs_generation_date
# 473  20181122  BFA18GEN-G049-Weekday-00-0111100             20190420
# service_id        BFA18GEN-G049-Weekday-00
# date                              20181225
# exception_type                           2
# Name: 126, dtype: object
#           date                service_id gtfs_generation_date
# 1308  20181225  BFA18GEN-G049-Weekday-00             20190420
# service_id        BFA18GEN-G049-Weekday-00-0111100
# date                                      20181225
# exception_type                                   2
# Name: 127, dtype: object
#           date                        service_id gtfs_generation_date
# 1309  20181225  BFA18GEN-G049-Weekday-00-0111100             20190420
# service_id        BFA18GEN-G049-Weekday-00
# date                              20190101
# exception_type                           2
# Name: 128, dtype: object
#           date                service_id gtfs_generation_date
# 1486  20190101  BFA18GEN-G049-Weekday-00             20190420
# service_id        BFA18GEN-G049-Weekday-00-0111100
# date                                      20190101
# exception_type                                   2
# Name: 129, dtype: object
#           date                        service_id gtfs_generation_date
# 1487  20190101  BFA18GEN-G049-Weekday-00-0111100             20190420
# service_id        BFA18GEN-G049-Weekday-00
# date                              20190218
# exception_type                           2
# Name: 130, dtype: object
#           date                service_id gtfs_generation_date
# 2708  20190218  BFA18GEN-G049-Weekday-00             20190420
# service_id        BFA18GEN-G049-Weekday-00-0111100
# date                                      20190218
# exception_type                                   2
# Name: 131, dtype: object
# Empty DataFrame
# Columns: [date, service_id, gtfs_generation_date]
# Index: []
# service_id        AFA18GEN-GS019-Weekday-00
# date                               20181122
# exception_type                            2
# Name: 132, dtype: object
#          date                 service_id gtfs_generation_date
# 464  20181122  AFA18GEN-GS019-Weekday-00             20190420
# service_id        AFA18GEN-GS019-Weekday-00
# date                               20181225
# exception_type                            2
# Name: 133, dtype: object
#           date                 service_id gtfs_generation_date
# 1300  20181225  AFA18GEN-GS019-Weekday-00             20190420
# service_id        AFA18GEN-GS019-Weekday-00
# date                               20190101
# exception_type                            2
# Name: 134, dtype: object
#           date                 service_id gtfs_generation_date
# 1478  20190101  AFA18GEN-GS019-Weekday-00             20190420
# service_id        AFA18GEN-GS019-Weekday-00
# date                               20190218
# exception_type                            2
# Name: 135, dtype: object
#           date                 service_id gtfs_generation_date
# 2700  20190218  AFA18GEN-GS019-Weekday-00             20190420
# service_id        BFA18GEN-H039-Weekday-00
# date                              20181122
# exception_type                           2
# Name: 136, dtype: object
#          date                service_id gtfs_generation_date
# 474  20181122  BFA18GEN-H039-Weekday-00             20190420
# service_id        BFA18GEN-H039-Weekday-00-0111100
# date                                      20181122
# exception_type                                   2
# Name: 137, dtype: object
#          date                        service_id gtfs_generation_date
# 475  20181122  BFA18GEN-H039-Weekday-00-0111100             20190420
# service_id        BFA18GEN-H039-Weekday-00
# date                              20181225
# exception_type                           2
# Name: 138, dtype: object
#           date                service_id gtfs_generation_date
# 1310  20181225  BFA18GEN-H039-Weekday-00             20190420
# service_id        BFA18GEN-H039-Weekday-00-0111100
# date                                      20181225
# exception_type                                   2
# Name: 139, dtype: object
#           date                        service_id gtfs_generation_date
# 1311  20181225  BFA18GEN-H039-Weekday-00-0111100             20190420
# service_id        BFA18GEN-H039-Weekday-00
# date                              20190101
# exception_type                           2
# Name: 140, dtype: object
#           date                service_id gtfs_generation_date
# 1488  20190101  BFA18GEN-H039-Weekday-00             20190420
# service_id        BFA18GEN-H039-Weekday-00-0111100
# date                                      20190101
# exception_type                                   2
# Name: 141, dtype: object
#           date                        service_id gtfs_generation_date
# 1489  20190101  BFA18GEN-H039-Weekday-00-0111100             20190420
# service_id        BFA18GEN-H039-Weekday-00
# date                              20190218
# exception_type                           2
# Name: 142, dtype: object
#           date                service_id gtfs_generation_date
# 2709  20190218  BFA18GEN-H039-Weekday-00             20190420
# service_id        BFA18GEN-H039-Weekday-00-0111100
# date                                      20190218
# exception_type                                   2
# Name: 143, dtype: object
# Empty DataFrame
# Columns: [date, service_id, gtfs_generation_date]
# Index: []
# service_id        BFA18GEN-J052-Weekday-00
# date                              20181122
# exception_type                           2
# Name: 144, dtype: object
#          date                service_id gtfs_generation_date
# 476  20181122  BFA18GEN-J052-Weekday-00             20190420
# service_id        BFA18GEN-J052-Weekday-00
# date                              20181225
# exception_type                           2
# Name: 145, dtype: object
#           date                service_id gtfs_generation_date
# 1312  20181225  BFA18GEN-J052-Weekday-00             20190420
# service_id        BFA18GEN-J052-Weekday-00
# date                              20190101
# exception_type                           2
# Name: 146, dtype: object
#           date                service_id gtfs_generation_date
# 1490  20190101  BFA18GEN-J052-Weekday-00             20190420
# service_id        BFA18GEN-J052-Weekday-00
# date                              20190218
# exception_type                           2
# Name: 147, dtype: object
#           date                service_id gtfs_generation_date
# 2710  20190218  BFA18GEN-J052-Weekday-00             20190420
# service_id        BFA18GEN-L045-Weekday-00
# date                              20181122
# exception_type                           2
# Name: 148, dtype: object
#          date                service_id gtfs_generation_date
# 477  20181122  BFA18GEN-L045-Weekday-00             20190420
# service_id        BFA18GEN-L045-Weekday-00
# date                              20181225
# exception_type                           2
# Name: 149, dtype: object
#           date                service_id gtfs_generation_date
# 1313  20181225  BFA18GEN-L045-Weekday-00             20190420
# service_id        BFA18GEN-L045-Weekday-00
# date                              20190101
# exception_type                           2
# Name: 150, dtype: object
#           date                service_id gtfs_generation_date
# 1491  20190101  BFA18GEN-L045-Weekday-00             20190420
# service_id        BFA18GEN-L045-Weekday-00
# date                              20190218
# exception_type                           2
# Name: 151, dtype: object
#           date                service_id gtfs_generation_date
# 2711  20190218  BFA18GEN-L045-Weekday-00             20190420
# service_id        BFA18GEN-M086-Weekday-00
# date                              20181122
# exception_type                           2
# Name: 152, dtype: object
#          date                service_id gtfs_generation_date
# 478  20181122  BFA18GEN-M086-Weekday-00             20190420
# service_id        BFA18GEN-M086-Weekday-00-0111100
# date                                      20181122
# exception_type                                   2
# Name: 153, dtype: object
#          date                        service_id gtfs_generation_date
# 479  20181122  BFA18GEN-M086-Weekday-00-0111100             20190420
# service_id        BFA18GEN-M086-Weekday-00
# date                              20181225
# exception_type                           2
# Name: 154, dtype: object
#           date                service_id gtfs_generation_date
# 1314  20181225  BFA18GEN-M086-Weekday-00             20190420
# service_id        BFA18GEN-M086-Weekday-00-0111100
# date                                      20181225
# exception_type                                   2
# Name: 155, dtype: object
#           date                        service_id gtfs_generation_date
# 1315  20181225  BFA18GEN-M086-Weekday-00-0111100             20190420
# service_id        BFA18GEN-M086-Weekday-00
# date                              20190101
# exception_type                           2
# Name: 156, dtype: object
#           date                service_id gtfs_generation_date
# 1492  20190101  BFA18GEN-M086-Weekday-00             20190420
# service_id        BFA18GEN-M086-Weekday-00-0111100
# date                                      20190101
# exception_type                                   2
# Name: 157, dtype: object
#           date                        service_id gtfs_generation_date
# 1493  20190101  BFA18GEN-M086-Weekday-00-0111100             20190420
# service_id        BFA18GEN-M086-Weekday-00
# date                              20190218
# exception_type                           2
# Name: 158, dtype: object
#           date                service_id gtfs_generation_date
# 2712  20190218  BFA18GEN-M086-Weekday-00             20190420
# service_id        BFA18GEN-M086-Weekday-00-0111100
# date                                      20190218
# exception_type                                   2
# Name: 159, dtype: object
# Empty DataFrame
# Columns: [date, service_id, gtfs_generation_date]
# Index: []
# service_id        BFA18GEN-N091-Weekday-00
# date                              20181122
# exception_type                           2
# Name: 160, dtype: object
#          date                service_id gtfs_generation_date
# 480  20181122  BFA18GEN-N091-Weekday-00             20190420
# service_id        BFA18GEN-N091-Weekday-00
# date                              20181225
# exception_type                           2
# Name: 161, dtype: object
#           date                service_id gtfs_generation_date
# 1316  20181225  BFA18GEN-N091-Weekday-00             20190420
# service_id        BFA18GEN-N091-Weekday-00
# date                              20190101
# exception_type                           2
# Name: 162, dtype: object
#           date                service_id gtfs_generation_date
# 1494  20190101  BFA18GEN-N091-Weekday-00             20190420
# service_id        BFA18GEN-N091-Weekday-00
# date                              20190218
# exception_type                           2
# Name: 163, dtype: object
#           date                service_id gtfs_generation_date
# 2713  20190218  BFA18GEN-N091-Weekday-00             20190420
# service_id        BFA18GEN-Q061-Weekday-00
# date                              20181122
# exception_type                           2
# Name: 164, dtype: object
#          date                service_id gtfs_generation_date
# 481  20181122  BFA18GEN-Q061-Weekday-00             20190420
# service_id        BFA18GEN-Q061-Weekday-00
# date                              20181225
# exception_type                           2
# Name: 165, dtype: object
#           date                service_id gtfs_generation_date
# 1317  20181225  BFA18GEN-Q061-Weekday-00             20190420
# service_id        BFA18GEN-Q061-Weekday-00
# date                              20190101
# exception_type                           2
# Name: 166, dtype: object
#           date                service_id gtfs_generation_date
# 1495  20190101  BFA18GEN-Q061-Weekday-00             20190420
# service_id        BFA18GEN-Q061-Weekday-00
# date                              20190218
# exception_type                           2
# Name: 167, dtype: object
#           date                service_id gtfs_generation_date
# 2714  20190218  BFA18GEN-Q061-Weekday-00             20190420
# service_id        BFA18GEN-R087-Weekday-00
# date                              20181122
# exception_type                           2
# Name: 168, dtype: object
#          date                service_id gtfs_generation_date
# 482  20181122  BFA18GEN-R087-Weekday-00             20190420
# service_id        BFA18GEN-R087-Weekday-00
# date                              20181225
# exception_type                           2
# Name: 169, dtype: object
#           date                service_id gtfs_generation_date
# 1318  20181225  BFA18GEN-R087-Weekday-00             20190420
# service_id        BFA18GEN-R087-Weekday-00
# date                              20190101
# exception_type                           2
# Name: 170, dtype: object
#           date                service_id gtfs_generation_date
# 1496  20190101  BFA18GEN-R087-Weekday-00             20190420
# service_id        BFA18GEN-R087-Weekday-00
# date                              20190218
# exception_type                           2
# Name: 171, dtype: object
#           date                service_id gtfs_generation_date
# 2715  20190218  BFA18GEN-R087-Weekday-00             20190420
# service_id        SIR-FA2017-SI017-Weekday-08
# date                                 20181122
# exception_type                              2
# Name: 172, dtype: object
#          date                   service_id gtfs_generation_date
# 483  20181122  SIR-FA2017-SI017-Weekday-08             20190420
# service_id        SIR-FA2017-SI017-Weekday-08
# date                                 20181225
# exception_type                              2
# Name: 173, dtype: object
#           date                   service_id gtfs_generation_date
# 1319  20181225  SIR-FA2017-SI017-Weekday-08             20190420
# service_id        SIR-FA2017-SI017-Weekday-08
# date                                 20190101
# exception_type                              2
# Name: 174, dtype: object
#           date                   service_id gtfs_generation_date
# 1497  20190101  SIR-FA2017-SI017-Weekday-08             20190420
# service_id        SIR-FA2017-SI017-Weekday-08
# date                                 20190218
# exception_type                              2
# Name: 175, dtype: object
#           date                   service_id gtfs_generation_date
# 2716  20190218  SIR-FA2017-SI017-Weekday-08             20190420
# service_id        ASP19GEN-1087-Weekday-00
# date                              20190527
# exception_type                           2
# Name: 3, dtype: object
#           date                service_id gtfs_generation_date
# 5238  20190527  ASP19GEN-1087-Weekday-00             20190509
# service_id        ASP19GEN-1087-Weekday-00
# date                              20190704
# exception_type                           2
# Name: 4, dtype: object
#           date                service_id gtfs_generation_date
# 6250  20190704  ASP19GEN-1087-Weekday-00             20190509
# service_id        ASP19GEN-1087-Weekday-00
# date                              20190902
# exception_type                           2
# Name: 5, dtype: object
#           date                service_id gtfs_generation_date
# 7842  20190902  ASP19GEN-1087-Weekday-00             20190509
# service_id        ASP19GEN-2097-Weekday-00
# date                              20190527
# exception_type                           2
# Name: 9, dtype: object
#           date                service_id gtfs_generation_date
# 5239  20190527  ASP19GEN-2097-Weekday-00             20190509
# service_id        ASP19GEN-2097-Weekday-00
# date                              20190704
# exception_type                           2
# Name: 10, dtype: object
#           date                service_id gtfs_generation_date
# 6251  20190704  ASP19GEN-2097-Weekday-00             20190509
# service_id        ASP19GEN-2097-Weekday-00
# date                              20190902
# exception_type                           2
# Name: 11, dtype: object
#           date                service_id gtfs_generation_date
# 7843  20190902  ASP19GEN-2097-Weekday-00             20190509
# service_id        ASP19GEN-3086-Weekday-00
# date                              20190527
# exception_type                           2
# Name: 15, dtype: object
#           date                service_id gtfs_generation_date
# 5240  20190527  ASP19GEN-3086-Weekday-00             20190509
# service_id        ASP19GEN-3086-Weekday-00
# date                              20190704
# exception_type                           2
# Name: 16, dtype: object
#           date                service_id gtfs_generation_date
# 6252  20190704  ASP19GEN-3086-Weekday-00             20190509
# service_id        ASP19GEN-3086-Weekday-00
# date                              20190902
# exception_type                           2
# Name: 17, dtype: object
#           date                service_id gtfs_generation_date
# 7844  20190902  ASP19GEN-3086-Weekday-00             20190509
# service_id        ASP19GEN-4097-Weekday-00
# date                              20190527
# exception_type                           2
# Name: 21, dtype: object
#           date                service_id gtfs_generation_date
# 5241  20190527  ASP19GEN-4097-Weekday-00             20190509
# service_id        ASP19GEN-4097-Weekday-00
# date                              20190704
# exception_type                           2
# Name: 22, dtype: object
#           date                service_id gtfs_generation_date
# 6253  20190704  ASP19GEN-4097-Weekday-00             20190509
# service_id        ASP19GEN-4097-Weekday-00
# date                              20190902
# exception_type                           2
# Name: 23, dtype: object
#           date                service_id gtfs_generation_date
# 7845  20190902  ASP19GEN-4097-Weekday-00             20190509
# service_id        ASP19GEN-5106-Weekday-00
# date                              20190527
# exception_type                           2
# Name: 27, dtype: object
#           date                service_id gtfs_generation_date
# 5242  20190527  ASP19GEN-5106-Weekday-00             20190509
# service_id        ASP19GEN-5106-Weekday-00
# date                              20190704
# exception_type                           2
# Name: 28, dtype: object
#           date                service_id gtfs_generation_date
# 6254  20190704  ASP19GEN-5106-Weekday-00             20190509
# service_id        ASP19GEN-5106-Weekday-00
# date                              20190902
# exception_type                           2
# Name: 29, dtype: object
#           date                service_id gtfs_generation_date
# 7846  20190902  ASP19GEN-5106-Weekday-00             20190509
# service_id        ASP19GEN-6086-Weekday-00
# date                              20190527
# exception_type                           2
# Name: 33, dtype: object
#           date                service_id gtfs_generation_date
# 5243  20190527  ASP19GEN-6086-Weekday-00             20190509
# service_id        ASP19GEN-6086-Weekday-00
# date                              20190704
# exception_type                           2
# Name: 34, dtype: object
#           date                service_id gtfs_generation_date
# 6255  20190704  ASP19GEN-6086-Weekday-00             20190509
# service_id        ASP19GEN-6086-Weekday-00
# date                              20190902
# exception_type                           2
# Name: 35, dtype: object
#           date                service_id gtfs_generation_date
# 7847  20190902  ASP19GEN-6086-Weekday-00             20190509
# service_id        ASP19GEN-GS019-Weekday-00
# date                               20190527
# exception_type                            2
# Name: 42, dtype: object
#           date                 service_id gtfs_generation_date
# 5245  20190527  ASP19GEN-GS019-Weekday-00             20190509
# service_id        ASP19GEN-GS019-Weekday-00
# date                               20190704
# exception_type                            2
# Name: 43, dtype: object
#           date                 service_id gtfs_generation_date
# 6257  20190704  ASP19GEN-GS019-Weekday-00             20190509
# service_id        ASP19GEN-GS019-Weekday-00
# date                               20190902
# exception_type                            2
# Name: 44, dtype: object
#           date                 service_id gtfs_generation_date
# 7849  20190902  ASP19GEN-GS019-Weekday-00             20190509
# service_id        ASP19SUPP-7059-Weekday-20
# date                               20190527
# exception_type                            2
# Name: 45, dtype: object
#           date                 service_id gtfs_generation_date
# 5246  20190527  ASP19SUPP-7059-Weekday-20             20190423
# service_id        ASP19SUPP-7059-Weekday-20
# date                               20190704
# exception_type                            2
# Name: 46, dtype: object
#           date                 service_id gtfs_generation_date
# 6258  20190704  ASP19SUPP-7059-Weekday-20             20190423
# service_id        ASP19SUPP-7059-Weekday-20
# date                               20190902
# exception_type                            2
# Name: 47, dtype: object
#           date                 service_id gtfs_generation_date
# 7850  20190902  ASP19SUPP-7059-Weekday-20             20190423
# service_id        BSP19GEN-A083-Weekday-00
# date                              20190527
# exception_type                           2
# Name: 51, dtype: object
#           date                service_id gtfs_generation_date
# 5247  20190527  BSP19GEN-A083-Weekday-00             20190509
# service_id        BSP19GEN-A083-Weekday-00
# date                              20190704
# exception_type                           2
# Name: 52, dtype: object
#           date                service_id gtfs_generation_date
# 6259  20190704  BSP19GEN-A083-Weekday-00             20190509
# service_id        BSP19GEN-A083-Weekday-00
# date                              20190902
# exception_type                           2
# Name: 53, dtype: object
#           date                service_id gtfs_generation_date
# 7851  20190902  BSP19GEN-A083-Weekday-00             20190509
# service_id        BSP19GEN-B080-Weekday-00
# date                              20190527
# exception_type                           2
# Name: 54, dtype: object
#           date                service_id gtfs_generation_date
# 5248  20190527  BSP19GEN-B080-Weekday-00             20190509
# service_id        BSP19GEN-B080-Weekday-00
# date                              20190704
# exception_type                           2
# Name: 55, dtype: object
#           date                service_id gtfs_generation_date
# 6260  20190704  BSP19GEN-B080-Weekday-00             20190509
# service_id        BSP19GEN-B080-Weekday-00
# date                              20190902
# exception_type                           2
# Name: 56, dtype: object
#           date                service_id gtfs_generation_date
# 7852  20190902  BSP19GEN-B080-Weekday-00             20190509
# service_id        BSP19GEN-C051-Weekday-00
# date                              20190527
# exception_type                           2
# Name: 60, dtype: object
#           date                service_id gtfs_generation_date
# 5249  20190527  BSP19GEN-C051-Weekday-00             20190509
# service_id        BSP19GEN-C051-Weekday-00
# date                              20190704
# exception_type                           2
# Name: 61, dtype: object
#           date                service_id gtfs_generation_date
# 6261  20190704  BSP19GEN-C051-Weekday-00             20190509
# service_id        BSP19GEN-C051-Weekday-00
# date                              20190902
# exception_type                           2
# Name: 62, dtype: object
#           date                service_id gtfs_generation_date
# 7853  20190902  BSP19GEN-C051-Weekday-00             20190509
# service_id        BSP19GEN-D077-Weekday-00
# date                              20190527
# exception_type                           2
# Name: 66, dtype: object
#           date                service_id gtfs_generation_date
# 5250  20190527  BSP19GEN-D077-Weekday-00             20190509
# service_id        BSP19GEN-D077-Weekday-00
# date                              20190704
# exception_type                           2
# Name: 67, dtype: object
#           date                service_id gtfs_generation_date
# 6262  20190704  BSP19GEN-D077-Weekday-00             20190509
# service_id        BSP19GEN-D077-Weekday-00
# date                              20190902
# exception_type                           2
# Name: 68, dtype: object
#           date                service_id gtfs_generation_date
# 7854  20190902  BSP19GEN-D077-Weekday-00             20190509
# service_id        BSP19GEN-E071-Weekday-00
# date                              20190527
# exception_type                           2
# Name: 72, dtype: object
#           date                service_id gtfs_generation_date
# 5251  20190527  BSP19GEN-E071-Weekday-00             20190509
# service_id        BSP19GEN-E071-Weekday-00
# date                              20190704
# exception_type                           2
# Name: 73, dtype: object
#           date                service_id gtfs_generation_date
# 6263  20190704  BSP19GEN-E071-Weekday-00             20190509
# service_id        BSP19GEN-E071-Weekday-00
# date                              20190902
# exception_type                           2
# Name: 74, dtype: object
#           date                service_id gtfs_generation_date
# 7855  20190902  BSP19GEN-E071-Weekday-00             20190509
# service_id        BSP19GEN-F072-Weekday-00
# date                              20190527
# exception_type                           2
# Name: 78, dtype: object
#           date                service_id gtfs_generation_date
# 5252  20190527  BSP19GEN-F072-Weekday-00             20190509
# service_id        BSP19GEN-F072-Weekday-00
# date                              20190704
# exception_type                           2
# Name: 79, dtype: object
#           date                service_id gtfs_generation_date
# 6264  20190704  BSP19GEN-F072-Weekday-00             20190509
# service_id        BSP19GEN-F072-Weekday-00
# date                              20190902
# exception_type                           2
# Name: 80, dtype: object
#           date                service_id gtfs_generation_date
# 7856  20190902  BSP19GEN-F072-Weekday-00             20190509
# service_id        BSP19GEN-FS011-Weekday-00
# date                               20190527
# exception_type                            2
# Name: 82, dtype: object
#           date                 service_id gtfs_generation_date
# 5253  20190527  BSP19GEN-FS011-Weekday-00             20190509
# service_id        BSP19GEN-FS011-Weekday-00
# date                               20190704
# exception_type                            2
# Name: 83, dtype: object
#           date                 service_id gtfs_generation_date
# 6265  20190704  BSP19GEN-FS011-Weekday-00             20190509
# service_id        BSP19GEN-FS011-Weekday-00
# date                               20190902
# exception_type                            2
# Name: 84, dtype: object
#           date                 service_id gtfs_generation_date
# 7857  20190902  BSP19GEN-FS011-Weekday-00             20190509
# service_id        BSP19GEN-H039-Weekday-00
# date                              20190527
# exception_type                           2
# Name: 90, dtype: object
#           date                service_id gtfs_generation_date
# 5254  20190527  BSP19GEN-H039-Weekday-00             20190509
# service_id        BSP19GEN-H039-Weekday-00
# date                              20190704
# exception_type                           2
# Name: 91, dtype: object
#           date                service_id gtfs_generation_date
# 6266  20190704  BSP19GEN-H039-Weekday-00             20190509
# service_id        BSP19GEN-H039-Weekday-00
# date                              20190902
# exception_type                           2
# Name: 92, dtype: object
#           date                service_id gtfs_generation_date
# 7858  20190902  BSP19GEN-H039-Weekday-00             20190509
# service_id        BSP19GEN-J052-Weekday-00
# date                              20190527
# exception_type                           2
# Name: 96, dtype: object
#           date                service_id gtfs_generation_date
# 5255  20190527  BSP19GEN-J052-Weekday-00             20190509
# service_id        BSP19GEN-J052-Weekday-00
# date                              20190704
# exception_type                           2
# Name: 97, dtype: object
#           date                service_id gtfs_generation_date
# 6268  20190704  BSP19GEN-J052-Weekday-00             20190509
# service_id        BSP19GEN-J052-Weekday-00
# date                              20190902
# exception_type                           2
# Name: 98, dtype: object
#           date                service_id gtfs_generation_date
# 7859  20190902  BSP19GEN-J052-Weekday-00             20190509
# service_id        BSP19GEN-M086-Weekday-00
# date                              20190527
# exception_type                           2
# Name: 99, dtype: object
#           date                service_id gtfs_generation_date
# 5256  20190527  BSP19GEN-M086-Weekday-00             20190509
# service_id        BSP19GEN-M086-Weekday-00
# date                              20190704
# exception_type                           2
# Name: 100, dtype: object
#           date                service_id gtfs_generation_date
# 6269  20190704  BSP19GEN-M086-Weekday-00             20190509
# service_id        BSP19GEN-M086-Weekday-00
# date                              20190902
# exception_type                           2
# Name: 101, dtype: object
#           date                service_id gtfs_generation_date
# 7860  20190902  BSP19GEN-M086-Weekday-00             20190509
# service_id        BSP19GEN-N091-Weekday-00
# date                              20190527
# exception_type                           2
# Name: 105, dtype: object
#           date                service_id gtfs_generation_date
# 5257  20190527  BSP19GEN-N091-Weekday-00             20190509
# service_id        BSP19GEN-N091-Weekday-00
# date                              20190704
# exception_type                           2
# Name: 106, dtype: object
#           date                service_id gtfs_generation_date
# 6271  20190704  BSP19GEN-N091-Weekday-00             20190509
# service_id        BSP19GEN-N091-Weekday-00
# date                              20190902
# exception_type                           2
# Name: 107, dtype: object
#           date                service_id gtfs_generation_date
# 7861  20190902  BSP19GEN-N091-Weekday-00             20190509
# service_id        BSP19GEN-Q062-Weekday-00
# date                              20190527
# exception_type                           2
# Name: 111, dtype: object
#           date                service_id gtfs_generation_date
# 5258  20190527  BSP19GEN-Q062-Weekday-00             20190509
# service_id        BSP19GEN-Q062-Weekday-00
# date                              20190704
# exception_type                           2
# Name: 112, dtype: object
#           date                service_id gtfs_generation_date
# 6272  20190704  BSP19GEN-Q062-Weekday-00             20190509
# service_id        BSP19GEN-Q062-Weekday-00
# date                              20190902
# exception_type                           2
# Name: 113, dtype: object
#           date                service_id gtfs_generation_date
# 7862  20190902  BSP19GEN-Q062-Weekday-00             20190509
# service_id        BSP19GEN-R087-Weekday-00
# date                              20190527
# exception_type                           2
# Name: 117, dtype: object
#           date                service_id gtfs_generation_date
# 5259  20190527  BSP19GEN-R087-Weekday-00             20190509
# service_id        BSP19GEN-R087-Weekday-00
# date                              20190704
# exception_type                           2
# Name: 118, dtype: object
#           date                service_id gtfs_generation_date
# 6273  20190704  BSP19GEN-R087-Weekday-00             20190509
# service_id        BSP19GEN-R087-Weekday-00
# date                              20190902
# exception_type                           2
# Name: 119, dtype: object
#           date                service_id gtfs_generation_date
# 7863  20190902  BSP19GEN-R087-Weekday-00             20190509
# service_id        BSP19SUPP-G049-Weekday-32
# date                               20190527
# exception_type                            2
# Name: 123, dtype: object
#           date                 service_id gtfs_generation_date
# 5260  20190527  BSP19SUPP-G049-Weekday-32             20190509
# service_id        BSP19SUPP-G049-Weekday-32
# date                               20190704
# exception_type                            2
# Name: 124, dtype: object
# ...
#            date                 service_id gtfs_generation_date
# 10196  20191128  BFA19GEN-FS011-Weekday-00             20191231
# service_id        BFA19GEN-FS011-Weekday-00
# date                               20191225
# exception_type                            2
# Name: 122, dtype: object
#            date                 service_id gtfs_generation_date
# 10881  20191225  BFA19GEN-FS011-Weekday-00             20191231
# service_id        BFA19GEN-FS011-Weekday-00
# date                               20200101
# exception_type                            2
# Name: 123, dtype: object
#            date                 service_id gtfs_generation_date
# 11059  20200101  BFA19GEN-FS011-Weekday-00             20191231
# service_id        BFA19GEN-FS011-Weekday-00
# date                               20200217
# exception_type                            2
# Name: 124, dtype: object
#            date                 service_id gtfs_generation_date
# 12253  20200217  BFA19GEN-FS011-Weekday-00             20200109
# service_id        BFA19GEN-G051-Weekday-00
# date                              20191128
# exception_type                           2
# Name: 125, dtype: object
#            date                service_id gtfs_generation_date
# 10197  20191128  BFA19GEN-G051-Weekday-00             20191231
# service_id        BFA19GEN-G051-Weekday-00-0111100
# date                                      20191128
# exception_type                                   2
# Name: 126, dtype: object
#            date                        service_id gtfs_generation_date
# 10198  20191128  BFA19GEN-G051-Weekday-00-0111100             20191231
# service_id        BFA19GEN-G051-Weekday-00
# date                              20191225
# exception_type                           2
# Name: 127, dtype: object
#            date                service_id gtfs_generation_date
# 10882  20191225  BFA19GEN-G051-Weekday-00             20191231
# service_id        BFA19GEN-G051-Weekday-00-0111100
# date                                      20191225
# exception_type                                   2
# Name: 128, dtype: object
#            date                        service_id gtfs_generation_date
# 10883  20191225  BFA19GEN-G051-Weekday-00-0111100             20191231
# service_id        BFA19GEN-G051-Weekday-00
# date                              20200101
# exception_type                           2
# Name: 129, dtype: object
#            date                service_id gtfs_generation_date
# 11060  20200101  BFA19GEN-G051-Weekday-00             20191231
# service_id        BFA19GEN-G051-Weekday-00-0111100
# date                                      20200101
# exception_type                                   2
# Name: 130, dtype: object
#            date                        service_id gtfs_generation_date
# 11061  20200101  BFA19GEN-G051-Weekday-00-0111100             20191231
# service_id        BFA19GEN-G051-Weekday-00
# date                              20200217
# exception_type                           2
# Name: 131, dtype: object
#            date                service_id gtfs_generation_date
# 12254  20200217  BFA19GEN-G051-Weekday-00             20200109
# service_id        BFA19GEN-G051-Weekday-00-0111100
# date                                      20200217
# exception_type                                   2
# Name: 132, dtype: object
# Empty DataFrame
# Columns: [date, service_id, gtfs_generation_date]
# Index: []
# service_id        AFA19GEN-GS019-Weekday-00
# date                               20191128
# exception_type                            2
# Name: 133, dtype: object
#            date                 service_id gtfs_generation_date
# 10189  20191128  AFA19GEN-GS019-Weekday-00             20191231
# service_id        AFA19GEN-GS019-Weekday-00
# date                               20191225
# exception_type                            2
# Name: 134, dtype: object
#            date                 service_id gtfs_generation_date
# 10874  20191225  AFA19GEN-GS019-Weekday-00             20191231
# service_id        AFA19GEN-GS019-Weekday-00
# date                               20200101
# exception_type                            2
# Name: 135, dtype: object
#            date                 service_id gtfs_generation_date
# 11052  20200101  AFA19GEN-GS019-Weekday-00             20191231
# service_id        AFA19GEN-GS019-Weekday-00
# date                               20200217
# exception_type                            2
# Name: 136, dtype: object
#            date                 service_id gtfs_generation_date
# 12246  20200217  AFA19GEN-GS019-Weekday-00             20200109
# service_id        BFA19GEN-H039-Weekday-00
# date                              20191128
# exception_type                           2
# Name: 137, dtype: object
#            date                service_id gtfs_generation_date
# 10199  20191128  BFA19GEN-H039-Weekday-00             20191231
# service_id        BFA19GEN-H039-Weekday-00-0111100
# date                                      20191128
# exception_type                                   2
# Name: 138, dtype: object
#            date                        service_id gtfs_generation_date
# 10200  20191128  BFA19GEN-H039-Weekday-00-0111100             20191231
# service_id        BFA19GEN-H039-Weekday-00
# date                              20191225
# exception_type                           2
# Name: 139, dtype: object
#            date                service_id gtfs_generation_date
# 10884  20191225  BFA19GEN-H039-Weekday-00             20191231
# service_id        BFA19GEN-H039-Weekday-00-0111100
# date                                      20191225
# exception_type                                   2
# Name: 140, dtype: object
#            date                        service_id gtfs_generation_date
# 10885  20191225  BFA19GEN-H039-Weekday-00-0111100             20191231
# service_id        BFA19GEN-H039-Weekday-00
# date                              20200101
# exception_type                           2
# Name: 141, dtype: object
#            date                service_id gtfs_generation_date
# 11062  20200101  BFA19GEN-H039-Weekday-00             20191231
# service_id        BFA19GEN-H039-Weekday-00-0111100
# date                                      20200101
# exception_type                                   2
# Name: 142, dtype: object
#            date                        service_id gtfs_generation_date
# 11063  20200101  BFA19GEN-H039-Weekday-00-0111100             20191231
# service_id        BFA19GEN-H039-Weekday-00
# date                              20200217
# exception_type                           2
# Name: 143, dtype: object
#            date                service_id gtfs_generation_date
# 12255  20200217  BFA19GEN-H039-Weekday-00             20200109
# service_id        BFA19GEN-H039-Weekday-00-0111100
# date                                      20200217
# exception_type                                   2
# Name: 144, dtype: object
# Empty DataFrame
# Columns: [date, service_id, gtfs_generation_date]
# Index: []
# service_id        BFA19GEN-J052-Weekday-00
# date                              20191128
# exception_type                           2
# Name: 145, dtype: object
#            date                service_id gtfs_generation_date
# 10201  20191128  BFA19GEN-J052-Weekday-00             20191231
# service_id        BFA19GEN-J052-Weekday-00
# date                              20191225
# exception_type                           2
# Name: 146, dtype: object
#            date                service_id gtfs_generation_date
# 10886  20191225  BFA19GEN-J052-Weekday-00             20191231
# service_id        BFA19GEN-J052-Weekday-00
# date                              20200101
# exception_type                           2
# Name: 147, dtype: object
#            date                service_id gtfs_generation_date
# 11064  20200101  BFA19GEN-J052-Weekday-00             20191231
# service_id        BFA19GEN-J052-Weekday-00
# date                              20200217
# exception_type                           2
# Name: 148, dtype: object
#            date                service_id gtfs_generation_date
# 12256  20200217  BFA19GEN-J052-Weekday-00             20200109
# service_id        BFA19SUPP-L047-Weekday-99
# date                               20191128
# exception_type                            2
# Name: 149, dtype: object
#            date                 service_id gtfs_generation_date
# 10207  20191128  BFA19SUPP-L047-Weekday-99             20191231
# service_id        BFA19SUPP-L047-Weekday-99
# date                               20191225
# exception_type                            2
# Name: 150, dtype: object
#            date                 service_id gtfs_generation_date
# 10892  20191225  BFA19SUPP-L047-Weekday-99             20191231
# service_id        BFA19SUPP-L047-Weekday-99
# date                               20200101
# exception_type                            2
# Name: 151, dtype: object
#            date                 service_id gtfs_generation_date
# 11070  20200101  BFA19SUPP-L047-Weekday-99             20191231
# service_id        BFA19SUPP-L047-Weekday-99
# date                               20200217
# exception_type                            2
# Name: 152, dtype: object
#            date                 service_id gtfs_generation_date
# 12262  20200217  BFA19SUPP-L047-Weekday-99             20200109
# service_id        BFA19GEN-M088-Weekday-00
# date                              20191128
# exception_type                           2
# Name: 153, dtype: object
#            date                service_id gtfs_generation_date
# 10202  20191128  BFA19GEN-M088-Weekday-00             20191231
# service_id        BFA19GEN-M088-Weekday-00-1111000
# date                                      20191128
# exception_type                                   2
# Name: 154, dtype: object
#            date                        service_id gtfs_generation_date
# 10203  20191128  BFA19GEN-M088-Weekday-00-1111000             20191231
# service_id        BFA19GEN-M088-Weekday-00
# date                              20191225
# exception_type                           2
# Name: 155, dtype: object
#            date                service_id gtfs_generation_date
# 10887  20191225  BFA19GEN-M088-Weekday-00             20191231
# service_id        BFA19GEN-M088-Weekday-00-1111000
# date                                      20191225
# exception_type                                   2
# Name: 156, dtype: object
#            date                        service_id gtfs_generation_date
# 10888  20191225  BFA19GEN-M088-Weekday-00-1111000             20191231
# service_id        BFA19GEN-M088-Weekday-00
# date                              20200101
# exception_type                           2
# Name: 157, dtype: object
#            date                service_id gtfs_generation_date
# 11065  20200101  BFA19GEN-M088-Weekday-00             20191231
# service_id        BFA19GEN-M088-Weekday-00-1111000
# date                                      20200101
# exception_type                                   2
# Name: 158, dtype: object
#            date                        service_id gtfs_generation_date
# 11066  20200101  BFA19GEN-M088-Weekday-00-1111000             20191231
# service_id        BFA19GEN-M088-Weekday-00
# date                              20200217
# exception_type                           2
# Name: 159, dtype: object
#            date                service_id gtfs_generation_date
# 12257  20200217  BFA19GEN-M088-Weekday-00             20200109
# service_id        BFA19GEN-M088-Weekday-00-1111000
# date                                      20200217
# exception_type                                   2
# Name: 160, dtype: object
#            date                        service_id gtfs_generation_date
# 12258  20200217  BFA19GEN-M088-Weekday-00-1111000             20200109
# service_id        BFA19GEN-N093-Weekday-00
# date                              20191128
# exception_type                           2
# Name: 161, dtype: object
#            date                service_id gtfs_generation_date
# 10204  20191128  BFA19GEN-N093-Weekday-00             20191231
# service_id        BFA19GEN-N093-Weekday-00
# date                              20191225
# exception_type                           2
# Name: 162, dtype: object
#            date                service_id gtfs_generation_date
# 10889  20191225  BFA19GEN-N093-Weekday-00             20191231
# service_id        BFA19GEN-N093-Weekday-00
# date                              20200101
# exception_type                           2
# Name: 163, dtype: object
#            date                service_id gtfs_generation_date
# 11067  20200101  BFA19GEN-N093-Weekday-00             20191231
# service_id        BFA19GEN-N093-Weekday-00
# date                              20200217
# exception_type                           2
# Name: 164, dtype: object
#            date                service_id gtfs_generation_date
# 12259  20200217  BFA19GEN-N093-Weekday-00             20200109
# service_id        BFA19GEN-Q062-Weekday-00
# date                              20191128
# exception_type                           2
# Name: 165, dtype: object
#            date                service_id gtfs_generation_date
# 10205  20191128  BFA19GEN-Q062-Weekday-00             20191231
# service_id        BFA19GEN-Q062-Weekday-00
# date                              20191225
# exception_type                           2
# Name: 166, dtype: object
#            date                service_id gtfs_generation_date
# 10890  20191225  BFA19GEN-Q062-Weekday-00             20191231
# service_id        BFA19GEN-Q062-Weekday-00
# date                              20200101
# exception_type                           2
# Name: 167, dtype: object
#            date                service_id gtfs_generation_date
# 11068  20200101  BFA19GEN-Q062-Weekday-00             20191231
# service_id        BFA19GEN-Q062-Weekday-00
# date                              20200217
# exception_type                           2
# Name: 168, dtype: object
#            date                service_id gtfs_generation_date
# 12260  20200217  BFA19GEN-Q062-Weekday-00             20200109
# service_id        BFA19GEN-R089-Weekday-00
# date                              20191128
# exception_type                           2
# Name: 169, dtype: object
#            date                service_id gtfs_generation_date
# 10206  20191128  BFA19GEN-R089-Weekday-00             20191231
# service_id        BFA19GEN-R089-Weekday-00
# date                              20191225
# exception_type                           2
# Name: 170, dtype: object
#            date                service_id gtfs_generation_date
# 10891  20191225  BFA19GEN-R089-Weekday-00             20191231
# service_id        BFA19GEN-R089-Weekday-00
# date                              20200101
# exception_type                           2
# Name: 171, dtype: object
#            date                service_id gtfs_generation_date
# 11069  20200101  BFA19GEN-R089-Weekday-00             20191231
# service_id        BFA19GEN-R089-Weekday-00
# date                              20200217
# exception_type                           2
# Name: 172, dtype: object
#            date                service_id gtfs_generation_date
# 12261  20200217  BFA19GEN-R089-Weekday-00             20200109
# service_id        SIR-FA2017-SI017-Weekday-08
# date                                 20191128
# exception_type                              2
# Name: 173, dtype: object
#            date                   service_id gtfs_generation_date
# 10208  20191128  SIR-FA2017-SI017-Weekday-08             20191112
# service_id        SIR-FA2017-SI017-Weekday-08
# date                                 20191225
# exception_type                              2
# Name: 174, dtype: object
#            date                   service_id gtfs_generation_date
# 10893  20191225  SIR-FA2017-SI017-Weekday-08             20191112
# service_id        SIR-FA2017-SI017-Weekday-08
# date                                 20200101
# exception_type                              2
# Name: 175, dtype: object
#            date                   service_id gtfs_generation_date
# 11071  20200101  SIR-FA2017-SI017-Weekday-08             20191112
# service_id        SIR-FA2017-SI017-Weekday-08
# date                                 20200217
# exception_type                              2
# Name: 176, dtype: object
#            date                   service_id gtfs_generation_date
# 12263  20200217  SIR-FA2017-SI017-Weekday-08             20200109

# %%
# Query calendar_result between configured dates
calendar_result = calendar_result[(calendar_result['value'] >= SEARCH_FROM_DATE) & (calendar_result['value'] <= SEARCH_TO_DATE)]

# %%
# Save updated calendar dataframe to a new file
calendar_result.to_csv('updated_calendar.csv', index=False)
